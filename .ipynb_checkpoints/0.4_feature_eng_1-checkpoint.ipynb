# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
from scipy.stats import ttest_ind
import numpy as np
from scipy.stats.stats import pearsonr
from IPython.display import display, Markdown, Latex
plt.style.use('ggplot')
from datetime import date
from statsmodels.stats.outliers_influence import variance_inflation_factor
data_path = '/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/'

from scipy.stats import norm
from seaborn_qqplot import pplot
import statsmodels.api as sm

import statsmodels.formula.api as smf

import numpy as np

import pandas
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_90683/2071815796.py:8: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import pearsonr

# %%
mobility_heat = pd.read_csv(data_path + 'mobility_heat/mobility_heat_clean_90.csv')

# %%
mobility_heat[mobility_heat['state'] == 'British Columbia']['county'].unique()
# Out:
# array(['Alberni-Clayoquot', 'Bulkley-Nechako', 'Capital', 'Cariboo',
#        'Central Kootenay', 'Central Okanagan', 'Columbia-Shuswap',
#        'Comox Valley', 'Cowichan Valley', 'East Kootenay',
#        'Fraser Valley', 'Fraser-Fort George', 'Kitimat-Stikine',
#        'Kootenay Boundary', 'Greater Vancouver', 'Mount Waddington',
#        'Nanaimo', 'North Okanagan', 'Okanagan-Similkameen', 'Peace River',
#        'Squamish-Lillooet', 'Strathcona', 'Sunshine Coast',
#        'Thompson-Nicola'], dtype=object)

# %%
for_plot = mobility_heat.melt(id_vars=['county', 'state', 'year', 'weekend'], value_vars=['retail_difference', 'grocery_pharmacy_difference', 'parks_difference', 'transit_difference', 'workplaces_difference', 'residential_difference'])

# %%
heatwave_control = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/heatwave_control/heatwave_control_clean_90.csv')

# %%
heatwave_control['Heat Wave Duration'] = heatwave_control['Heat Wave Duration_x']

# %%
heatwave_control.drop(['Heat Wave Duration_x', 'Heat Wave Duration_y'], axis=1, inplace=True)

# %%
heatwave_control.groupby('state')['Heat Wave Duration'].describe()
# Out:
#                   count      mean       std  min  25%  50%  75%   max
# state
# British Columbia  357.0  4.212885  2.196665  2.0  2.0  3.0  6.0  11.0
# California        765.0  3.819608  2.160178  2.0  2.0  3.0  5.0  11.0
# Oregon            572.0  3.388112  1.821183  2.0  2.0  3.0  4.0  11.0
# Washington        559.0  3.822898  1.936939  2.0  2.0  3.0  5.0  12.0

# %%
heatwave_control.rename(columns={'datetime': 'date'}, inplace=True)
mobility_heat.rename(columns={'datetime': 'date'}, inplace=True)
heatwave_control.drop_duplicates(['location', 'date'], inplace=True)

# %% [markdown]
# ## Build Intensity Variable

# %% [markdown]
# ### Basic intensity is simply the 2m temperature

# %% [markdown]
# ### Clean/Add control day temperature

# %%
full_df = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/daily_max/max_temps/max_temps.csv')
full_df['datetime'] = pd.to_datetime(full_df['datetime'])
us_temps = full_df[full_df['state'].isin(['California', 'Oregon', 'Washington'])]
us_temps['county'] = us_temps['county'] + ' County'
us_temps['location'] = us_temps['county'] + ', ' + us_temps['state']

ca_temps = full_df[full_df['state'] == 'British Columbia']
ca_temps['location'] = ca_temps['county'] + ', ' + ca_temps['state']

nw_temps = us_temps.append(ca_temps)
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_90683/98854216.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_temps['county'] = us_temps['county'] + ' County'
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_90683/98854216.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_temps['location'] = us_temps['county'] + ', ' + us_temps['state']
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_90683/98854216.py:8: SettingWithCopyWarning:
# ...

# %%
holidays = pd.read_csv('/Users/shivyucel/Downloads/holidays.csv')

# %%
holidays['date'] = pd.to_datetime(holidays['date'])

# %%
mobility_heat['holiday'] = [1 if (x in holidays['date'].values) & (y=='British Columbia') else 0 for (x,y) in zip(mobility_heat['date_heat'], mobility_heat['state'])]
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_90683/3898142776.py:1: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mobility_heat['holiday'] = [1 if (x in holidays['date'].values) & (y=='British Columbia') else 0 for (x,y) in zip(mobility_heat['date_heat'], mobility_heat['state'])]

# %%
mobility_heat = mobility_heat[mobility_heat['holiday'] != 1]

# %%
us_hols = pd.read_csv('/Users/shivyucel/Downloads/archive/400_Years_of_Generated_Dates_and_Holidays.csv')

# %%
us_hols = us_hols[us_hols['IS_HOLIDAY'] == 1]

# %%
us_hols['A_DATE'] = pd.to_datetime(us_hols['A_DATE'])

# %%
mobility_heat['us_holiday_heat'] = [1 if (x in us_hols['A_DATE'].values) & (y != 'British Columbia') else 0 for (x,y) in zip(mobility_heat['date_heat'], mobility_heat['state'])]
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_90683/1400198879.py:1: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mobility_heat['us_holiday_heat'] = [1 if (x in us_hols['A_DATE'].values) & (y != 'British Columbia') else 0 for (x,y) in zip(mobility_heat['date_heat'], mobility_heat['state'])]

# %%
mobility_heat['us_holiday'] = [1 if (x in us_hols['A_DATE'].values) & (y != 'British Columbia') else 0 for (x,y) in zip(mobility_heat['date_control'], mobility_heat['state'])]
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_90683/2607035615.py:1: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mobility_heat['us_holiday'] = [1 if (x in us_hols['A_DATE'].values) & (y != 'British Columbia') else 0 for (x,y) in zip(mobility_heat['date_control'], mobility_heat['state'])]

# %%
mobility_heat = mobility_heat[mobility_heat['us_holiday'] == 0]

# %%
mobility_heat[['date_heat','control_day']] = mobility_heat[['date_heat','control_day']].apply(pd.to_datetime) #if conversion required

mobility_heat['C'] = (mobility_heat['date_heat'] - mobility_heat['control_day']).dt.days

# %%
mobility_heat = mobility_heat.merge(nw_temps[['datetime', 'temperature_2m', 'location']], left_on=['location', 'control_day'], right_on=['location', 'datetime'], suffixes=('_heat', '_control'))

# %%
mobility_heat
# Out:
#       Unnamed: 0.1  Unnamed: 0 country_region_code country_region  \
# 0                0       48495                  US  United States
# 1                1       48496                  US  United States
# 2                2       48533                  US  United States
# 3                3       48534                  US  United States
# 4                4       48566                  US  United States
# ...            ...         ...                 ...            ...
# 7410          7410       13380                  CA         Canada
# 7411          7411       13381                  CA         Canada
# 7412          7412       13382                  CA         Canada
# 7413          7413       13383                  CA         Canada
# 7414          7414       13384                  CA         Canada
#
#                  state           county  metro_area  iso_3166_2_code  \
# 0           California   Alameda County         NaN              NaN
# ...

# %%
np.corrcoef(mobility_heat['temperature_2m_heat'], mobility_heat['temperature_2m_control'])
# Out:
# array([[1.        , 0.77897449],
#        [0.77897449, 1.        ]])

# %%
mobility_heat = mobility_heat.merge(nw_temps[['datetime', 'temperature_2m', 'location']], left_on=['location', 'control_day'], right_on=['location', 'datetime'], suffixes=('_heat', '_control'))

# %% [markdown]
# #### Check Correlation between heat wave and control temperature

# %%
np.corrcoef(mobility_heat['temperature_2m_heat'], mobility_heat['temperature_2m_control'])
# Out:
# array([[1.        , 0.77897449],
#        [0.77897449, 1.        ]])

# %% [markdown]
# ### Create/explore temperature difference variable

# %%
mobility_heat['temp_diff'] = mobility_heat['temperature_2m_heat'] - mobility_heat['temperature_2m_control']

# %%
mobility_heat['temp_diff'].describe()
# Out:
# count    7415.000000
# mean        7.858529
# std         3.782163
# min         1.303160
# 25%         5.055799
# 50%         7.178236
# 75%         9.935929
# max        25.339561
# Name: temp_diff, dtype: float64

# %%
sns.histplot(mobility_heat, x='temp_diff')
plt.title("Temperature Difference (heat wave vs. control)")
plt.tight_layout()
plt.savefig(data_path + '/img/12_09_2023/temp_diff_dist.png')

# %% [markdown]
# ### Build Duration Variable
# * Duration of heat wave (in days)
# * Build variable showing which day of a heatwave it is

# %%
# Formatting column names and merging dataframes

# %%
heatwave_control.reset_index(inplace=True)

# %%
duration_IDs = heatwave_control.drop_duplicates('heat_ID')[['heat_ID', 'Heat Wave Duration']  ]

# %%
duration_IDs.columns = ['heat_ID', 'Heat Wave Duration']

# %%
duration_IDs
# Out:
#                                    heat_ID  Heat Wave Duration
# 0     8ef32a02-7165-40e1-b559-635edbcd1cc4                 3.0
# 1     dbfe460c-49c7-493a-bc88-c033e6920abd                 2.0
# 2     e803b7b8-7ff3-42bd-9785-ef7956662df6                 3.0
# 3     51149baa-07b2-4878-b339-d7a43d56cf35                 2.0
# 4     f136d5c5-7c4b-486f-8697-ef0d292efbbd                 2.0
# ...                                    ...                 ...
# 8452  d606ab21-bec1-4ca7-b2e0-8f4d5b9fd1a5                 2.0
# 8453  8f3237f5-d3e9-4cc4-b8a7-3bdb0f3d950b                 2.0
# 8454  a966766e-c300-474e-be09-8034c33df814                 2.0
# 8457  168f7db5-41c5-4511-a139-de496e5b9e32                 2.0
# 8499  32f81075-fb25-4394-b385-54e38c674981                 2.0
#
# [2253 rows x 2 columns]

# %%
heatwave_control.drop('Heat Wave Duration', axis=1, inplace=True)

# %%
heatwave_control = heatwave_control.merge(duration_IDs, on='heat_ID', how='left')

# %%
heatwave_control.groupby('state')['Heat Wave Duration'].describe()
# Out:
#                    count      mean       std  min  25%  50%  75%   max
# state
# British Columbia  1504.0  5.355053  2.422780  2.0  3.0  5.0  7.0  11.0
# California        2922.0  5.039699  2.611393  2.0  3.0  4.0  7.0  11.0
# Oregon            1938.0  4.365325  2.203783  2.0  2.0  4.0  6.0  11.0
# Washington        2137.0  4.802527  2.250121  2.0  3.0  4.0  6.0  12.0

# %%
heatwave_control.groupby('state')['heat_ID'].describe()
# Out:
#                  count unique                                   top freq
# state
# British Columbia  1504    357  723b5750-1de5-4eed-8713-a03ca2a62bab   11
# California        2922    765  586e723f-ba69-4722-906b-68aced80ad67   11
# Oregon            1938    572  75dca50f-0cd8-4bad-b208-6e60c2b683f0   11
# Washington        2137    559  d2676138-0e44-4e3b-a520-d57535b348fa   12

# %%
heatwave_control.drop_duplicates(['location', 'date'], inplace=True)

# %%
heatwave_control['dur_ranking'] = heatwave_control['Heat Wave Duration'].rank(pct=True)

# %%
heat_stage = heatwave_control.groupby('heat_ID').apply(lambda x: x.date.sort_values().rank()).reset_index()

# %%
heat_stage.columns=['heat_ID', 'index', 'stage']

# %%
heat_stage
# Out:
#                                    heat_ID  index  stage
# 0     00536be6-cad7-4a1b-97fa-1b763337df85   4201    1.0
# 1     00536be6-cad7-4a1b-97fa-1b763337df85   4299    2.0
# 2     00536be6-cad7-4a1b-97fa-1b763337df85   4398    3.0
# 3     00536be6-cad7-4a1b-97fa-1b763337df85   4464    4.0
# 4     0055a761-bfb7-4d65-84f7-1eb77e31e66f    976    1.0
# ...                                    ...    ...    ...
# 8496  ffe375ec-afda-4d82-a5a2-57fdac046dc3   6978    3.0
# 8497  ffe375ec-afda-4d82-a5a2-57fdac046dc3   7003    4.0
# 8498  ffe6c341-1616-4128-8f73-eba5974d059d   2059    1.0
# 8499  ffe6c341-1616-4128-8f73-eba5974d059d   2061    2.0
# 8500  ffe6c341-1616-4128-8f73-eba5974d059d   2062    3.0
#
# [8501 rows x 3 columns]

# %%
heat_stage['stage'].max()
# Out:
# 12.0

# %%
x = heat_stage.merge(duration_IDs, on='heat_ID')

# %%
(x['stage'] / x['Heat Wave Duration']).max()
# Out:
# 1.0

# %%
heatwave_control
# Out:
#       index  Unnamed: 0         county  day  month  year  temperature_2m  \
# 0         0           0     Sacramento    3      6  2020       38.026975
# 1         1           1   Contra Costa    3      6  2020       35.016445
# 2         2           2    San Joaquin    3      6  2020       38.130510
# 3         3           3    Santa Clara    3      6  2020       33.600732
# 4         4           4     Santa Cruz    3      6  2020       26.056117
# ...     ...         ...            ...  ...    ...   ...             ...
# 8496   8496        8496        Whatcom   11      9  2022       26.356694
# 8497   8497        8497        Cowlitz   11      9  2022       31.802246
# 8498   8498        8498  Central Coast   11      9  2022       22.823252
# 8499   8499        8499         Orange   27      9  2022       32.984351
# 8500   8500        8500         Orange   28      9  2022       32.077327
#
#                  state        date                         location       pct  \
# ...

# %%
heatwave_control = heatwave_control.merge(heat_stage, on=['index', 'heat_ID'])

# %%
heatwave_control
# Out:
#       index  Unnamed: 0         county  day  month  year  temperature_2m  \
# 0         0           0     Sacramento    3      6  2020       38.026975
# 1         1           1   Contra Costa    3      6  2020       35.016445
# 2         2           2    San Joaquin    3      6  2020       38.130510
# 3         3           3    Santa Clara    3      6  2020       33.600732
# 4         4           4     Santa Cruz    3      6  2020       26.056117
# ...     ...         ...            ...  ...    ...   ...             ...
# 8496   8496        8496        Whatcom   11      9  2022       26.356694
# 8497   8497        8497        Cowlitz   11      9  2022       31.802246
# 8498   8498        8498  Central Coast   11      9  2022       22.823252
# 8499   8499        8499         Orange   27      9  2022       32.984351
# 8500   8500        8500         Orange   28      9  2022       32.077327
#
#                  state        date                         location  ...  \
# ...

# %%
heatwave_control.groupby('state')['heat_ID'].describe()
# Out:
#                  count unique                                   top freq
# state
# British Columbia  1504    357  723b5750-1de5-4eed-8713-a03ca2a62bab   11
# California        2922    765  586e723f-ba69-4722-906b-68aced80ad67   11
# Oregon            1938    572  75dca50f-0cd8-4bad-b208-6e60c2b683f0   11
# Washington        2137    559  d2676138-0e44-4e3b-a520-d57535b348fa   12

# %%
heatwave_control['date'] = pd.to_datetime(heatwave_control['date'])

# %%
heatwave_control['stage'].max()
# Out:
# 12.0

# %%
mobility_heat['state'].unique()
# Out:
# array(['California', 'Oregon', 'Washington', 'British Columbia'],
#       dtype=object)

# %%
heatwave_control_us = heatwave_control[heatwave_control['state'].isin(['California', 'Oregon', 'Washington'])]
heatwave_control_us['county'] = heatwave_control_us['county'] + ' County'
heatwave_control_us['location'] = heatwave_control_us['county'] + ', ' + heatwave_control_us['state']

heatwave_control_ca = heatwave_control[heatwave_control['state'] == 'British Columbia']
heatwave_control_ca['location'] = heatwave_control_ca['county'] + ', ' + heatwave_control_ca['state']

heatwave_control = heatwave_control_us.append(heatwave_control_ca)
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_90683/714079828.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heatwave_control_us['county'] = heatwave_control_us['county'] + ' County'
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_90683/714079828.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heatwave_control_us['location'] = heatwave_control_us['county'] + ', ' + heatwave_control_us['state']
# ...

# %%
mobility_heat
# Out:
#       Unnamed: 0.1  Unnamed: 0 country_region_code country_region  \
# 0                0       48495                  US  United States
# 1                1       48496                  US  United States
# 2                2       48533                  US  United States
# 3                3       48534                  US  United States
# 4                4       48566                  US  United States
# ...            ...         ...                 ...            ...
# 7410          7410       13380                  CA         Canada
# 7411          7411       13381                  CA         Canada
# 7412          7412       13382                  CA         Canada
# 7413          7413       13383                  CA         Canada
# 7414          7414       13384                  CA         Canada
#
#                  state           county  metro_area  iso_3166_2_code  \
# 0           California   Alameda County         NaN              NaN
# ...

# %%
mobility_heat = mobility_heat.merge(heatwave_control[['heat_ID', 'location', 'date', 'Heat Wave Duration', 'dur_ranking', 'stage']], left_on=['location', 'date_heat'], right_on=['location', 'date'])

# %%
mobility_heat.reset_index(inplace=True)

# %%
mobility_heat[['date_heat','control_day']] = mobility_heat[['date_heat','control_day']].apply(pd.to_datetime) #if conversion required

mobility_heat['C'] = (mobility_heat['date_heat'] - mobility_heat['control_day']).dt.days

# %%
mobility_heat['C'].describe()
# Out:
# count    7415.000000
# mean        9.727310
# std         6.808259
# min       -14.000000
# 25%         7.000000
# 50%         7.000000
# 75%        14.000000
# max        49.000000
# Name: C, dtype: float64

# %%
mobility_heat[mobility_heat['Heat Wave Duration'] >= 12]['year'].unique()
# Out:
# array([2021])

# %%
mobility_heat['state'].unique()
# Out:
# array(['California', 'Oregon', 'Washington', 'British Columbia'],
#       dtype=object)

# %%
x = mobility_heat.copy()
x['stage_frac'] = (mobility_heat['stage'] / mobility_heat['Heat Wave Duration'] )

# %%
mobility_heat.to_csv(data_path + 'mobility_heat/mobility_heat_vars_clean_90.csv')

# %%
max_lengths = mobility_heat.drop_duplicates('heat_ID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[605], line 1
# ----> 1 max_lengths = mobility_heat.drop_duplicates('heat_ID')
#
# File ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py:6672, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6670 inplace = validate_bool_kwarg(inplace, "inplace")
# ...

# %%
max_lengths['stage'].value_counts()

# %%
sns.displot(mobility_heat, x='stage', bins=range(19))
plt.xlabel("Heat Wave Day")
plt.xticks(ticks=range(19))
plt.title("Stage of Heat Wave (nth day)")
plt.tight_layout()
plt.savefig(data_path + '/img/12_09_2023/heat_wave_day.png')

# %%
sns.displot(mobility_heat, x='weekend', bins=range(3), hue='weekend')
plt.xlabel("Weekend/Weekday")
plt.xticks(ticks=range(3))
plt.title("Weekday (0) vs. Weekday (1)")
plt.tight_layout()


plt.savefig(data_path + '/img/12_09_2023/weekend_weekday.png')

# %%
mobility_heat.to_csv(data_path + 'mobility_heat/mobility_heat_90_w_vars_v1.csv')

# %% [markdown]
# ### Get population density variables

# %%
import pandas as pd
us_areas = pd.read_csv(data_path + 'census/US/pop_dens.csv')
ca_areas = pd.read_html("https://en.wikipedia.org/wiki/List_of_regional_districts_of_British_Columbia")

# %%
us_areas = us_areas[['NAME', 'State', 'B01001_calc_PopDensity']]

# %%
ca_areas = ca_areas[1][['Regional district', 'Density (per km2)']]
ca_areas.replace({'–': '-'}, regex=True, inplace=True)
ca_areas.replace('Metro Vancouver', 'Greater Vancouver', inplace=True)

# %%
us_areas.columns = ['county', 'state', 'popdens']

# %%
ca_areas.columns = ['county', 'popdens']
ca_areas['state'] = 'British Columbia'

# %%
pop_dens = pd.concat([us_areas, ca_areas])

# %%
pop_dens['location'] = pop_dens['county'] + ', ' + pop_dens['state']

# %%
mobility_heat = mobility_heat.merge(pop_dens[['location', 'popdens']], on='location', how='left')

# %% [markdown]
# ### Exploring Bins n Shit

# %%
sns.lmplot(mobility_heat, x='temp_diff', y = 'parks_difference', scatter_kws = {'alpha':0.6}, line_kws={'color':'blue'})
plt.ylabel("Temperature Difference")
plt.xlabel("Heat Temperature")
plt.tight_layout()
#plt.savefig(data_path + '/img/12_09_2023/temp_diff_park_slope.png')

# %%
binning  = mobility_heat.copy().drop_duplicates('location')

# %%
binning['Population Density Quartile'] = pd.qcut(binning['popdens'], 4, labels=False)

# %%
mobility_heat = mobility_heat.merge(binning[['location', 'Population Density Quartile']])

# %%
mobility_heat['Temperature Difference Quartile'] = pd.qcut(mobility_heat['temp_diff'], 4, labels=False)
mobility_heat['Heat Wave Temperature Quartile'] = pd.qcut(mobility_heat['temperature_2m_heat'], 4, labels=False)
mobility_heat['Temp Diff Quartile'] = pd.qcut(mobility_heat['temp_diff'], 4, labels=False)


mobility_heat['Parks Mobility Difference (%)'] = mobility_heat['parks_difference']
mobility_heat['Residential Mobility Difference (%)'] = mobility_heat['residential_difference']

# %%
test = mobility_heat.copy()

# %%
test = test[test['weekend'] == 1]

# %%
mobility_heat
# Out:
#       index  Unnamed: 0.1  Unnamed: 0 country_region_code country_region  \
# 0         0             0       48495                  US  United States
# 1         1             1       48496                  US  United States
# 2         2             2       48533                  US  United States
# 3         3             3       48534                  US  United States
# 4         4             4       48567                  US  United States
# ...     ...           ...         ...                 ...            ...
# 6293   6293          6291       13361                  CA         Canada
# 6294   6294          6292       13368                  CA         Canada
# 6295   6295          6293       13369                  CA         Canada
# 6296   6296          6294       13383                  CA         Canada
# 6297   6297          6295       13384                  CA         Canada
#
#                  state           county  metro_area  iso_3166_2_code  \
# ...

# %%
sns.catplot( mobility_heat, x='Heat Wave Temperature Quartile', y='Parks Mobility Difference (%)', hue='Temp Diff Quartile',  kind='box', legend_out=False, aspect=1, height=7)#, col_wrap=2, legend_out=False, showfliers=False, sharex=True, margin_titles=True)     # scatter_kws = {'alpha':0.6}, line_kws={'color':'blue'})

plt.suptitle("Park Mobility Change \n Separated by Heat Wave Temp and Temp Difference", fontsize=20)
plt.tight_layout()
#plt.savefig(data_path + '/img/12_09_2023/state_dens_boxes_parks_weekend.png')
plt.show()

# %%
sns.catplot(mobility_heat, x='Temperature Difference Quartile', y='parks_difference', hue='state', col='Heat Wave Temperature Quartile', kind='box'),# scatter_kws = {'alpha':0.6}, line_kws={'color':'blue'})
plt.ylabel("Difference in park visitation")
plt.xlabel("Heat wave temperature bins")
plt.tight_layout()
#plt.savefig(data_path + '/img/12_09_2023/temp_abs_park_slope.png')

# %% [markdown]
# ## Thinking about the models

# %%
sns.lmplot(mobility_heat, x='temp_diff', y='parks_difference', col='state', hue='state', scatter_kws = {'alpha':0.1})
plt.tight_layout()
#plt.savefig(data_path + '/img/12_09_2023/temp_diff_slopes.png')

# %%
sns.lmplot(mobility_heat, x='temperature_2m_heat', y='parks_difference', col='state', hue='state', scatter_kws = {'alpha':0.1})
plt.tight_layout()
#plt.savefig(data_path + '/img/12_09_2023/temp_diff_slopes.png')

# %% [markdown]
# #### Check directionality of relationships between temperature and parks visitation

# %%
sns.lmplot(mobility_heat, x='temp_diff', y='parks_difference', hue='location', scatter_kws = {'alpha':0.0}, line_kws = {'linewidth':0.3}, ci=None, legend=False)
plt.title("Temperature difference and park mobility change \n Controlling for counties")
plt.tight_layout()
plt.savefig(data_path + '/img/12_09_2023/temp_diff_slopes.png')

# %% [markdown]
# #### Check VIF of heat and control variables -- Acceptable!

# %%
# load statmodels functions
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# compute the vif for all given features
def compute_vif(considered_features):
    
    X = mobility_heat[considered_features]
    # the calculation of variance inflation requires a constant
    X['intercept'] = 1
    
    # create dataframe to store vif values
    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif[vif['Variable']!='intercept']
    return vif

# features to consider removing
considered_features = ['temperature_2m_heat','temp_diff', 'stage', 'weekend', 'popdens']


# compute vif 
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_16438/577316974.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['intercept'] = 1
#               Variable       VIF
# 0  temperature_2m_heat  1.020086
# 4              popdens  1.008846
# 2                stage  1.006972
# 3              weekend  1.005331
# 1            temp_diff  1.000343

# %% [markdown]
# ### Explore model options

# %% [markdown]
# #### OLS

# %%
# load statmodels functions
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# compute the vif for all given features
def compute_vif(considered_features):
    
    X = mobility_heat[considered_features]
    # the calculation of variance inflation requires a constant
    X['intercept'] = 1
    
    # create dataframe to store vif values
    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif[vif['Variable']!='intercept']
    return vif

# features to consider removing
considered_features = ['temperature_2m_heat', 'temp_diff', 'stage', 'weekend', 'popdens']


# compute vif 
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_16438/1994469863.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['intercept'] = 1
#               Variable       VIF
# 0  temperature_2m_heat  1.020086
# 4              popdens  1.008846
# 2                stage  1.006972
# 3              weekend  1.005331
# 1            temp_diff  1.000343

# %%
mobility_heat[mobility_heat['county'] == 'Capital']['parks_difference'].mean()
# Out:
# 9.6

# %%
mobility_heat[mobility_heat['state'] == 'British Columbia'][['county','parks_difference', 'popdens']].dropna()['county'].unique()
# Out:
# array(['Capital', 'Central Okanagan', 'Columbia-Shuswap', 'Comox Valley',
#        'Fraser Valley', 'Greater Vancouver', 'Nanaimo', 'Thompson-Nicola'],
#       dtype=object)

# %%
mobility_heat['popdens'].describe()
# Out:
# count    6298.000000
# mean      119.719833
# std       519.479031
# min         0.275373
# 25%         4.413807
# 50%        18.312327
# 75%        55.992733
# max      7168.190471
# Name: popdens, dtype: float64

# %%
mobility_heat[mobility_heat['grocery_pharmacy_difference'].isnull()]['popdens'].describe()
# Out:
# count    1641.000000
# mean        7.768789
# std        11.929378
# min         0.275373
# 25%         1.794896
# 50%         3.901559
# 75%         8.689019
# max       151.165670
# Name: popdens, dtype: float64

# %%
df = mobility_heat.dropna(subset='parks_difference')

# %%
df['remove'] = [True if abs(x) >= df['parks_difference'].mean() + (2 * df['parks_difference'].std()) else False for x in df['parks_difference'] ]
df = df[df['remove'] == False]
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_9529/3641278699.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['remove'] = [True if abs(x) >= df['parks_difference'].mean() + (2 * df['parks_difference'].std()) else False for x in df['parks_difference'] ]

# %%
mod_fixed = smf.ols(formula='parks_difference ~ temperature_2m_heat*temp_diff + stage + weekend', data=df)
res_fixed = mod_fixed.fit()
res_fixed.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       parks_difference   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     67.89
# Date:                Thu, 21 Sep 2023   Prob (F-statistic):           2.62e-67
# Time:                        09:37:27   Log-Likelihood:                -14384.
# No. Observations:                2928   AIC:                         2.878e+04
# Df Residuals:                    2922   BIC:                         2.882e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %%
performance = pd.DataFrame()
performance["residuals"] = res_fixed.resid.values
performance["temp_diff"] = df.temp_diff
performance["predicted"] = res_fixed.fittedvalues

sns.lmplot(x = "predicted", y = "residuals", data = performance)

# %%
from scipy.stats import norm
from seaborn_qqplot import pplot
pplot(performance, x="residuals", y=norm, kind='qq', height=6, aspect=1, display_kws={"identity":True})
#notes: skewed left -- source: https://seankross.com/2016/02/29/A-Q-Q-Plot-Dissection-Kit.html

# %%
df = mobility_heat.dropna(subset='parks_difference')
df['remove'] = [True if abs(x) >= df['parks_difference'].mean() + (2 * df['parks_difference'].std()) else False for x in df['parks_difference'] ]
df = df[df['remove'] == False]
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_16438/3641278699.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['remove'] = [True if abs(x) >= df['parks_difference'].mean() + (2 * df['parks_difference'].std()) else False for x in df['parks_difference'] ]

# %%
df['temperature_2m_heat'] = df['temperature_2m_heat']  - df['temperature_2m_heat'].mean()
df['temp_diff'] = df['temp_diff']  - df['temp_diff'].mean()

# %%
md_fixed = smf.mixedlm("parks_difference ~ temperature_2m_heat*temp_diff + stage + weekend", df, groups=df['location'])
res_fixed=md_fixed.fit()
res_fixed.summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Mixed Linear Model Regression Results
# ...
# Model:                MixedLM    Dependent Variable:    parks_difference
# No. Observations:     2744       Method:                REML
# No. Groups:           94         Scale:                 358.7708
# Min. group size:      1          Log-Likelihood:        -12047.5229
# Max. group size:      56         Converged:             Yes
# Mean group size:      29.2
# ------------------------------------------------------------------------
#                               Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                     -2.993    1.165 -2.570 0.010 -5.276 -0.710
# temperature_2m_heat           -1.010    0.157 -6.424 0.000 -1.318 -0.702
# temp_diff                      1.328    0.116 11.485 0.000  1.101  1.555
# ...

# %%
performance = pd.DataFrame()
performance["residuals"] = res_fixed.resid.values
performance["temp_diff"] = df.temp_diff
performance["predicted"] = res_fixed.fittedvalues

# %%
sns.lmplot(x = "predicted", y = "residuals", data = performance)

# %%
pplot(performance, x="residuals", y=norm, kind='qq', height=6, aspect=1, display_kws={"identity":True})
#notes: skewed left -- source: https://seankross.com/2016/02/29/A-Q-Q-Plot-Dissection-Kit.html

# %%
md_random = smf.mixedlm("parks_difference ~ temperature_2m_heat*temp_diff + stage + weekend + popdens", df, groups=df['location'], re_formula = 'temperature_2m_heat')
res_random = md_random.fit()
res_random.summary()
# Out:
# /Users/shivyucel/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/shivyucel/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /Users/shivyucel/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/shivyucel/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# ...

# %%
from scipy.stats.distributions import chi2
def likelihood_ratio(llmin, llmax):
    return(2*(llmax-llmin))


LR = likelihood_ratio(-12053, -12055)


p = chi2.sf(LR, 1) # L2 has 1 DoF more than L1

print('p: %.30f' % p) 

# p: 0.000000121315450836607258011741
# Out:
# p: 1.000000000000000000000000000000

# %%
results = pd.DataFrame.from_dict(res_random.random_effects).transpose().reset_index()

# %%
results.columns = ['location', 'intercept', 'slope']

# %%
results = results.merge(mobility_heat, on='location').drop_duplicates('location')

# %%
performance = pd.DataFrame()
performance["residuals"] = res_random.resid.values
performance["temp_diff"] = df.temp_diff
performance["predicted"] = res_random.fittedvalues

# %%
sns.lmplot(x = "predicted", y = "residuals", data = performance)

# %%
pplot(performance, x="residuals", y=norm, kind='qq', height=6, aspect=1, display_kws={"identity":True})
#notes: skewed left -- source: https://seankross.com/2016/02/29/A-Q-Q-Plot-Dissection-Kit.html

# %%
from statsmodels.stats.anova import anova_lm

# %%
anovaResults = anova_lm(md_fixed, md_random)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[469], line 1
# ----> 1 anovaResults = anova_lm(md_fixed, md_random)
#
# NameError: name 'md_fixed' is not defined

# %%
bc_mobility_heat = mobility_heat[mobility_heat['state'] == "Oregon"]

# %% [markdown]
# ### Check for normality of residuals

# %%
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.diagnostic import het_white

# %%
white_test = het_white(res.resid,  res.model.exog)

# %%
white_test
# Out:
# (154.1973454270194,
#  2.1511744350527892e-19,
#  5.755612164198911,
#  5.329904220220967e-20)

# %% [markdown]
# ### Check Normality of Intensity Variable

# %%
sns.displot(data=mobility_heat, x='temperature_2m', kde=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 sns.displot(data=mobility_heat, x='temperature_2m', kde=True)
#
# File ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/seaborn/distributions.py:2125, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2111 def displot(
#    2112     data=None, *,
#    2113     # Vector variables
#    (...)
#    2122     **kwargs,
#    2123 ):
# -> 2125     p = _DistributionFacetPlotter(
#    2126         data=data,
#    2127         variables=_DistributionFacetPlotter.get_semantics(locals())
#    2128     )
#    2130     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    2132     _check_argument("kind", ["hist", "kde", "ecdf"], kind)
#
# ...

# %%
sns.residplot(data=mobility_heat, x="temperature_2m", y="parks_difference", lowess=True, line_kws=dict(color="r"))

# %%
from scipy.stats import norm
from seaborn_qqplot import pplot
pplot(mobility_heat, x="temperature_2m", y=norm, kind='qq', height=4, aspect=2, display_kws={"identity":True})
#notes: skewed left -- source: https://seankross.com/2016/02/29/A-Q-Q-Plot-Dissection-Kit.html

# %% [markdown]
# ### Check normality of Duration Variable

# %%
sns.displot(data=mobility_heat, x='Heat Wave Duration', kde=False)

# %%
sns.residplot(data=mobility_heat, x="Heat Wave Duration", y="parks_difference", lowess=True, line_kws=dict(color="r"))

# %%
from scipy.stats import norm
from seaborn_qqplot import pplot
pplot(performance, x="residuals", y=norm, kind='qq', height=6, aspect=2, display_kws={"identity":True})
#notes: skewed left -- source: https://seankross.com/2016/02/29/A-Q-Q-Plot-Dissection-Kit.html

# %% [markdown]
# ### Duration

# %%
dic = {}

for category in ['retail', 'grocery_pharmacy', 'parks', 'transit', 'workplaces', 'residential']:
    
    dic[category] = {}

    
    for state in mobility_heat['state_x'].unique():
        
        
        dic[category][state] = {}
        
        temp = mobility_heat[mobility_heat['state_x'] == state]
        
        temp.dropna(subset=[f'{category}_difference','dur_ranking'], inplace=True)
        
        print(len(temp))
        pearson = pearsonr(x=temp['dur_ranking'], y=temp[f'{category}_difference'])
        
        dic[category][state] = {}
        
        dic[category][state]['coef'] = pearson[0]
        dic[category][state]['pvalue'] = pearson[1]
        
        print(f'{category}, {state}, {pearson}')

# %%
df = pd.DataFrame.from_dict(dic)
df = pd.DataFrame(df.unstack()).reset_index()
df['coef'] = [x['coef'] for x in df[0]]
df['pvalue'] = [x['pvalue'] for x in df[0]]

# %% [markdown]
# ### Intensity

# %%
dic = {}

for category in ['retail', 'grocery_pharmacy', 'parks', 'transit', 'workplaces', 'residential']:
    
    dic[category] = {}

    for year in [2020, 2021, 2022]:
        
        for state in mobility_heat['state_x'].unique():

            dic[category][state] = {}

            temp = mobility_heat[mobility_heat['state_x'] == state]

            temp.dropna(subset=[f'{category}_difference','intensity_rank'], inplace=True)

            print(len(temp))
            pearson = pearsonr(x=temp['intensity_rank'], y=temp[f'{category}_difference'])

            dic[category][state] = {}

            dic[category][state]['coef'] = pearson[0]
            dic[category][state]['pvalue'] = pearson[1]

            print(f'{category}, {state}, {pearson}')

# %%
df = pd.DataFrame.from_dict(dic)
df = pd.DataFrame(df.unstack()).reset_index()
df['coef'] = [x['coef'] for x in df[0]]
df['pvalue'] = [x['pvalue'] for x in df[0]]

# %%
df.head()
# Out:
#             level_0           level_1  \
# 0            retail        California
# 1            retail            Oregon
# 2            retail        Washington
# 3            retail  British Columbia
# 4  grocery_pharmacy        California
#
#                                                    0      coef        pvalue
# 0  {'coef': -0.05788034373799563, 'pvalue': 0.008... -0.057880  8.158101e-03
# 1  {'coef': -0.13650071754222184, 'pvalue': 5.646... -0.136501  5.646565e-06
# 2  {'coef': -0.06260484988334175, 'pvalue': 0.030... -0.062605  3.081222e-02
# 3  {'coef': 0.20730290014923392, 'pvalue': 2.7252...  0.207303  2.725215e-10
# 4  {'coef': -0.12577115826984236, 'pvalue': 2.450... -0.125771  2.450205e-08

# %%
to_plot_intensity = df.melt(id_vars=['level_0', 'level_1'], value_vars=['coef', 'pvalue'])

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.barplot(df, x='level_1', hue='level_0', y='coef')
plt.title("Correlation Coefficient of Mobility Change and Heat Wave Intensity")
plt.xlabel("State")
plt.ylabel("Coefficient")
plt.savefig(data_path + 'results/imgs/state_intensity_coefs.png', dpi=300)

# %%
mobility_heat.columns
# Out:
# Index(['index', 'Unnamed: 0.1', 'Unnamed: 0', 'country_region_code',
#        'country_region', 'state', 'county', 'metro_area', 'iso_3166_2_code',
#        'census_fips_code', 'place_id', 'date_heat', 'retail_heat',
#        'grocery_pharmacy_heat', 'parks_heat', 'transit_heat',
#        'workplaces_heat', 'residential_heat', 'year', 'location', 'geometry',
#        'control_day', 'temperature_2m_heat', 'date_control', 'retail_control',
#        'grocery_pharmacy_control', 'parks_control', 'transit_control',
#        'workplaces_control', 'residential_control', 'retail_difference',
#        'grocery_pharmacy_difference', 'parks_difference', 'transit_difference',
#        'workplaces_difference', 'residential_difference', 'day_of_week',
#        'weekend', 'datetime', 'temperature_2m_control', 'temp_diff', 'heat_ID',
#        'date', 'Heat Wave Duration', 'dur_ranking', 'stage', 'popdens'],
#       dtype='object')

# %%
mobility_heat.groupby('location').median()[['retail_difference',
       'grocery_pharmacy_difference', 'parks_difference', 'transit_difference',
       'workplaces_difference', 'residential_difference', 'temp_diff', 'temperature_2m_control', 'temperature_2m_heat', 'popdens']]
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_74047/3631903244.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mobility_heat.groupby('location').median()[['retail_difference',
#                                      retail_difference  \
# location
# Adams County, Washington                           2.0
# Alameda County, California                        -1.0
# Alberni-Clayoquot, British Columbia               11.0
# Amador County, California                         -3.0
# Asotin County, Washington                          0.0
# ...                                                ...
# Whitman County, Washington                         3.0
# Yakima County, Washington                          0.0
# Yamhill County, Oregon                            -1.0
# ...
