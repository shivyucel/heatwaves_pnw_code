# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
from scipy.stats import ttest_ind
import numpy as np
from scipy.stats.stats import pearsonr
from IPython.display import display, Markdown, Latex
plt.style.use('ggplot')


data_path = '/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/'
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97178/1559749542.py:8: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import pearsonr

# %% [markdown]
# ### Load mobility data files

# %%
mobility_data = pd.DataFrame()
for year in [2020, 2021, 2022]:
    df = pd.read_csv(data_path + f'google_mobility/clean/US_{year}.csv')
    mobility_data = mobility_data.append(df)
    
for year in [2020, 2021, 2022]:
    df = pd.read_csv(data_path + f'google_mobility/clean/CA_{year}.csv')
    mobility_data = mobility_data.append(df)
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97178/343977191.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path + f'google_mobility/clean/US_{year}.csv')
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97178/343977191.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mobility_data = mobility_data.append(df)
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97178/343977191.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path + f'google_mobility/clean/US_{year}.csv')
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97178/343977191.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
nw_mobility = mobility_data[mobility_data['state'].isin(['Washington', 'California', 'Oregon', 'British Columbia'])]

# %%
nw_mobility = nw_mobility.dropna(subset='county')

# %%
nw_mobility['location'] = nw_mobility['county'] + ', ' + nw_mobility['state']

# %%
nw_mobility[nw_mobility['state'] == 'British Columbia']['county'].unique()
# Out:
# array(['Alberni-Clayoquot', 'Bulkley-Nechako', 'Capital', 'Cariboo',
#        'Central Kootenay', 'Central Okanagan', 'Columbia-Shuswap',
#        'Comox Valley', 'Cowichan Valley', 'East Kootenay',
#        'Fraser Valley', 'Fraser-Fort George', 'Kitimat-Stikine',
#        'Kootenay Boundary', 'Metro Vancouver', 'Mount Waddington',
#        'Nanaimo', 'North Coast', 'North Okanagan', 'Okanagan-Similkameen',
#        'Peace River', 'qathet Regional District', 'Squamish-Lillooet',
#        'Strathcona', 'Sunshine Coast Regional District',
#        'Thompson-Nicola'], dtype=object)

# %%
nw_mobility['date'] = pd.to_datetime(nw_mobility['date'])

# %%
nw_mobility['year'] = [x.year for x in nw_mobility['date']]

# %%
nw_mobility.groupby('year')['residential'].describe()
# Out:
#         count      mean       std   min  25%  50%   75%   max
# year
# 2020  34246.0  8.391257  6.318755  -7.0  4.0  8.0  12.0  37.0
# 2021  43782.0  5.519666  4.721171 -10.0  2.0  5.0   8.0  34.0
# 2022  34591.0  3.433986  3.661568  -8.0  1.0  3.0   5.0  29.0

# %%
nw_mobility.replace('Sunshine Coast Regional District', "Sunshine Coast", inplace=True)
nw_mobility.replace('Metro Vancouver', "Greater Vancouver", inplace=True)
nw_mobility['location'] = nw_mobility['county'] + ', ' + nw_mobility['state']

# %% [markdown]
# ### Load/Clean County Shapefiles

# %%
shapes = gpd.read_file(f'/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/pac_nw_shapes/pac_nw_shapes.shp')
shapes.to_crs(epsg=3857, inplace=True)

# %%
shapes.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Load US Data and add word "County"

# %%
us_shapes = shapes[shapes['state'].isin(['Washington', 'California', 'Oregon'])]

# %%
us_shapes['county_names'] = us_shapes['county'] + ' County'
# Out:
# /Users/shivyucel/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/geopandas/geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
us_shapes['location'] = us_shapes['county_names'] + ', ' + us_shapes['state']

# %% [markdown]
# #### Merge Canada Data

# %%
ca_shapes = shapes[shapes['state'].isin(['British Columbia'])]
ca_shapes['location'] = ca_shapes['county'] + ', ' + ca_shapes['state']
# Out:
# /Users/shivyucel/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/geopandas/geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
ca_shapes['county'].unique()
# Out:
# array(['Squamish-Lillooet', 'Stikine', 'Sunshine Coast',
#        'Thompson-Nicola', 'Comox Valley', 'Strathcona',
#        'Alberni-Clayoquot', 'Bulkley-Nechako', 'Capital', 'Cariboo',
#        'Central Coast', 'Central Kootenay', 'Central Okanagan',
#        'Columbia-Shuswap', 'Cowichan Valley', 'East Kootenay',
#        'Fraser-Fort George', 'Fraser Valley', 'Greater Vancouver',
#        'Kitimat-Stikine', 'Kootenay Boundary', 'Mount Waddington',
#        'Nanaimo', 'North Okanagan', 'Northern Rockies',
#        'Okanagan-Similkameen', 'Peace River', 'Powell River',
#        'Skeena-Queen Charlotte'], dtype=object)

# %%
nw_shapes = us_shapes.append(ca_shapes)
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97178/1136810035.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nw_shapes = us_shapes.append(ca_shapes)

# %% [markdown]
# ### Check missing counties in mobility data

# %%
nw_shapes.plot()
# Out:
# <AxesSubplot:>

# %%
len(nw_shapes['location'].unique())
# Out:
# 162

# %%
len(nw_mobility['location'].unique())
# Out:
# 152

# %%
nw_mobility[nw_mobility['state'] == 'British Columbia']['county'].unique()
# Out:
# array(['Alberni-Clayoquot', 'Bulkley-Nechako', 'Capital', 'Cariboo',
#        'Central Kootenay', 'Central Okanagan', 'Columbia-Shuswap',
#        'Comox Valley', 'Cowichan Valley', 'East Kootenay',
#        'Fraser Valley', 'Fraser-Fort George', 'Kitimat-Stikine',
#        'Kootenay Boundary', 'Greater Vancouver', 'Mount Waddington',
#        'Nanaimo', 'North Coast', 'North Okanagan', 'Okanagan-Similkameen',
#        'Peace River', 'qathet Regional District', 'Squamish-Lillooet',
#        'Strathcona', 'Sunshine Coast', 'Thompson-Nicola'], dtype=object)

# %% [markdown]
# ### Merge Mobility Data with Shapes

# %%
nw_mobility.replace('Sunshine Coast Regional District', "Sunshine Coast", inplace=True)
nw_mobility.replace('Metro Vancouver', "Greater Vancouver", inplace=True)
nw_mobility['location'] = nw_mobility['county'] + ', ' + nw_mobility['state']

# %%
for x in nw_shapes['location'].unique():
    if x not in nw_mobility['location'].values:
        print(x)
# Out:
# Gilliam County, Oregon
# Wheeler County, Oregon
# Alpine County, California
# Sierra County, California
# Columbia County, Washington
# Garfield County, Washington
# Wahkiakum County, Washington
# Stikine, British Columbia
# Central Coast, British Columbia
# Northern Rockies, British Columbia
# Powell River, British Columbia
# Skeena-Queen Charlotte, British Columbia

# %%
nw_shapes.plot()
# Out:
# <AxesSubplot:>

# %%
nw_mobility = nw_mobility.merge(nw_shapes[['geometry', 'location']], on='location')

# %%
nw_mobility = gpd.GeoDataFrame(nw_mobility, crs='epsg:3857')

# %%
len(nw_mobility['location'].unique())
# Out:
# 150

# %%
nw_mobility.drop_duplicates('location')
# Out:
#           Unnamed: 0 country_region_code country_region             state  \
# 0              48386                  US  United States        California
# 4870           48707                  US  United States        California
# 5819           49003                  US  United States        California
# 6793           49324                  US  United States        California
# 7760           49638                  US  United States        California
# ...              ...                 ...            ...               ...
# 11112658       12509                  CA         Canada  British Columbia
# 11113626       13096                  CA         Canada  British Columbia
# 11115562       13411                  CA         Canada  British Columbia
# 13938070       13720                  CA         Canada  British Columbia
# 14232260       14016                  CA         Canada  British Columbia
#
#                      county  metro_area  iso_3166_2_code  census_fips_code  \
# ...

# %%
nw_shapes = nw_shapes[['geometry', 'location']]

# %%
nw_shapes
# Out:
#                                                 geometry  \
# 0      POLYGON ((-13193581.432 5573111.891, -13193561...
# 1      POLYGON ((-13783237.999 5518825.768, -13783237...
# 2      POLYGON ((-13677615.742 5664739.285, -13677613...
# 3      POLYGON ((-13792762.627 5807872.586, -13792749...
# 4      POLYGON ((-13781552.271 5798433.084, -13781538...
# ...                                                  ...
# 29302  POLYGON ((-14532778.636 7095676.436, -14532775...
# 29303  POLYGON ((-14504394.858 7140891.108, -14504392...
# 29304  POLYGON ((-14526100.282 7246867.376, -14526099...
# 29305  POLYGON ((-14822679.318 7153917.074, -14822676...
# 29306  POLYGON ((-14758369.175 6999052.746, -14758368...
#
#                                        location
# 0                          Baker County, Oregon
# 1                         Benton County, Oregon
# 2                      Clackamas County, Oregon
# 3                        Clatsop County, Oregon
# ...

# %%
nw_shapes.to_file(data_path + 'nw_clean_shape/nw_clean_shape.shp')

# %% [markdown]
# ### Load/Clean Simple Heatwave Data

# %%
#heatwave_control = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/heatwave_control/heatwave_control_90_v2.csv')
heatwave_control = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/heatwave_control/heatwave_control_clean_90.csv')

# %%
heatwave_control.rename(columns={'datetime': 'date'}, inplace=True)

# %%
from datetime import timedelta
from dateutil.parser import parse

# %%
heatwave_control['control_day'] = [parse(x) for x in heatwave_control['control_day']]
heatwave_control['date'] = [parse(x) for x in heatwave_control['date']]

# %%
(heatwave_control['date'] - heatwave_control['control_day']).describe()
# Out:
# count                         8501
# mean     9 days 15:26:14.073638395
# std      6 days 19:03:51.653144553
# min             -14 days +00:00:00
# 25%                7 days 00:00:00
# 50%                7 days 00:00:00
# 75%               14 days 00:00:00
# max               49 days 00:00:00
# dtype: object

# %%
heatwave_control['diff'] = (heatwave_control['date'] - heatwave_control['control_day'])

# %%
temp = pd.DataFrame(heatwave_control['diff'].value_counts()).sort_index()

# %%
temp.columns = ['Number of Instances']

# %%
sns.barplot(temp, y=temp.index, x='Number of Instances')
plt.ylabel("Heat and Control Difference")
# Out:
# Text(0, 0.5, 'Heat and Control Difference')

# %%
us_heatwave_control = heatwave_control[heatwave_control['state'].isin(['California', 'Oregon', 'Washington'])]
us_heatwave_control['county'] = us_heatwave_control['county'] + ' County'
us_heatwave_control['location'] = us_heatwave_control['county'] + ', ' + us_heatwave_control['state']
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97178/937797548.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_heatwave_control['county'] = us_heatwave_control['county'] + ' County'
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97178/937797548.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_heatwave_control['location'] = us_heatwave_control['county'] + ', ' + us_heatwave_control['state']

# %%
ca_heatwave_control = heatwave_control[heatwave_control['state'] == 'British Columbia']
ca_heatwave_control['location'] = ca_heatwave_control['county'] + ', ' + ca_heatwave_control['state']
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97178/1480314334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_heatwave_control['location'] = ca_heatwave_control['county'] + ', ' + ca_heatwave_control['state']

# %%
nw_heatwave_control = us_heatwave_control.append(ca_heatwave_control)
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97178/3925333777.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nw_heatwave_control = us_heatwave_control.append(ca_heatwave_control)

# %%
nw_heatwave_control[nw_heatwave_control['state'] == 'British Columbia']['county'].unique()
# Out:
# array(['Central Coast', 'Alberni-Clayoquot', 'Strathcona', 'Powell River',
#        'Squamish-Lillooet', 'Sunshine Coast', 'Capital', 'Fraser Valley',
#        'Greater Vancouver', 'Mount Waddington', 'Cowichan Valley',
#        'Kootenay Boundary', 'North Okanagan', 'Fraser-Fort George',
#        'Okanagan-Similkameen', 'East Kootenay', 'Comox Valley',
#        'Columbia-Shuswap', 'Central Kootenay', 'Nanaimo',
#        'Thompson-Nicola', 'Central Okanagan', 'Cariboo', 'Peace River',
#        'Stikine', 'Kitimat-Stikine', 'Skeena-Queen Charlotte',
#        'Bulkley-Nechako', 'Northern Rockies'], dtype=object)

# %%
nw_heatwave_control
# Out:
#       Unnamed: 0               county  day  month  year  temperature_2m  \
# 0              0    Sacramento County    3      6  2020       38.026975
# 1              1  Contra Costa County    3      6  2020       35.016445
# 2              2   San Joaquin County    3      6  2020       38.130510
# 3              3   Santa Clara County    3      6  2020       33.600732
# 4              4    Santa Cruz County    3      6  2020       26.056117
# ...          ...                  ...  ...    ...   ...             ...
# 8487        8487    Greater Vancouver   11      9  2022       28.090763
# 8489        8489      Cowichan Valley   11      9  2022       27.027910
# 8491        8491              Capital   11      9  2022       24.890646
# 8492        8492    Alberni-Clayoquot   11      9  2022       25.919110
# 8498        8498        Central Coast   11      9  2022       22.823252
#
#                  state       date                             location  \
# ...

# %%
nw_heatwave_control.to_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/heatwave_control/simple_format_heatwave_control_v6_95.csv')

# %% [markdown]
# ### Merge Mobility with Heat Data

# %%
nw_mobility.drop_duplicates(['location', 'date'], inplace=True)

# %%
mobility_heat = nw_mobility.merge(nw_heatwave_control[['control_day', 'temperature_2m', 'location', 'date', 'heat_ID']], on=['location', 'date'])

# %%
#merge mobility data associated with control dates
mobility_heat = mobility_heat.merge(nw_mobility[['location', 'date', 'retail', 'grocery_pharmacy', 'parks', 'transit', 'workplaces', 'residential']], left_on=['location', 'control_day'], right_on=['location', 'date'], suffixes=['_heat', '_control'])

# %%
#calculate differences between heat and control 
mobility_heat['retail_difference'] = mobility_heat['retail_heat'] - mobility_heat['retail_control']
mobility_heat['grocery_pharmacy_difference'] = mobility_heat['grocery_pharmacy_heat'] - mobility_heat['grocery_pharmacy_control']
mobility_heat['parks_difference'] = mobility_heat['parks_heat'] - mobility_heat['parks_control']
mobility_heat['transit_difference'] = mobility_heat['transit_heat'] - mobility_heat['transit_control']
mobility_heat['workplaces_difference'] = mobility_heat['workplaces_heat'] - mobility_heat['workplaces_control']
mobility_heat['residential_difference'] = mobility_heat['residential_heat'] - mobility_heat['residential_control']

# %%
mobility_heat['day_of_week'] = [x.day_of_week for x in mobility_heat['date_heat']]
mobility_heat['weekend'] = [1 if x in [5,6] else 0 for x in mobility_heat['day_of_week']]

# %%
mobility_heat.reset_index(drop=True,inplace=True)

# %%
mobility_heat.drop_duplicates(['location', 'date_heat'])['county'].unique()
# Out:
# array(['Alameda County', 'Amador County', 'Butte County',
#        'Calaveras County', 'Colusa County', 'Contra Costa County',
#        'Del Norte County', 'El Dorado County', 'Fresno County',
#        'Glenn County', 'Humboldt County', 'Imperial County',
#        'Inyo County', 'Kern County', 'Kings County', 'Lake County',
#        'Lassen County', 'Los Angeles County', 'Madera County',
#        'Marin County', 'Mariposa County', 'Mendocino County',
#        'Merced County', 'Modoc County', 'Mono County', 'Monterey County',
#        'Napa County', 'Nevada County', 'Orange County', 'Placer County',
#        'Plumas County', 'Riverside County', 'Sacramento County',
#        'San Benito County', 'San Bernardino County', 'San Diego County',
#        'San Francisco County', 'San Joaquin County',
#        'San Luis Obispo County', 'San Mateo County',
#        'Santa Barbara County', 'Santa Clara County', 'Santa Cruz County',
#        'Shasta County', 'Siskiyou County', 'Solano County',
# ...

# %%
mobility_heat.to_csv(data_path + 'mobility_heat/mobility_heat_clean_90.csv')

# %% [markdown]
# ### Melt dataframe for plotting

# %%
for_plot = mobility_heat.melt(id_vars=['county', 'state', 'year'], value_vars=['retail_difference', 'grocery_pharmacy_difference', 'parks_difference', 'transit_difference', 'workplaces_difference', 'residential_difference'])

# %% [markdown]
# ## All States and Years Analysis

# %%
fig, ((ax0, ax1, ax2), (ax3, ax4, ax5)) = plt.subplots(nrows=2, ncols=3, figsize=(20, 20))
sns.pointplot(mobility_heat, y='retail_difference', ax=ax0)
sns.violinplot(mobility_heat, y='grocery_pharmacy_difference', ax=ax1)
sns.violinplot(mobility_heat, y='parks_difference', ax=ax2)
sns.violinplot(mobility_heat, y='transit_difference', ax=ax3)
sns.violinplot(mobility_heat, y='workplaces_difference', ax=ax4)
sns.violinplot(mobility_heat, y='residential_difference', ax=ax5)
# Out:
# <AxesSubplot:ylabel='residential_difference'>

# %%
pd.DataFrame(mobility_heat['retail_difference'].describe()).transpose()
# Out:
#                     count      mean       std   min  25%  50%  75%   max
# retail_difference  5382.0  0.924935  8.873428 -81.0 -3.0  0.0  3.0  76.0

# %%
pd.DataFrame(mobility_heat['grocery_pharmacy_difference'].describe()).transpose()
# Out:
#                               count     mean       std   min  25%  50%  75%  \
# grocery_pharmacy_difference  4655.0  1.41783  7.990679 -44.0 -2.0  1.0  4.0
#
#                               max
# grocery_pharmacy_difference  83.0

# %%
pd.DataFrame(mobility_heat['parks_difference'].describe()).transpose()
# Out:
#                    count      mean        std    min   25%  50%  75%    max
# parks_difference  2928.0 -4.533128  34.765468 -257.0 -19.0 -7.0  6.0  320.0

# %%
pd.DataFrame(mobility_heat['transit_difference'].describe()).transpose()
# Out:
#                      count      mean        std   min  25%  50%  75%   max
# transit_difference  3515.0 -0.702703  11.482118 -98.0 -5.0 -1.0  3.0  91.0

# %%
pd.DataFrame(mobility_heat['workplaces_difference'].describe()).transpose()
# Out:
#                         count      mean       std   min  25%  50%  75%   max
# workplaces_difference  6143.0 -0.965652  9.211716 -59.0 -2.0  0.0  1.0  50.0

# %%
pd.DataFrame(mobility_heat['residential_difference'].describe()).transpose()
# Out:
#                          count      mean       std   min  25%  50%  75%   max
# residential_difference  5066.0  0.070667  2.132284 -12.0 -1.0  0.0  1.0  14.0

# %%
data_path
# Out:
# '/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/'

# %%
fig, ax = plt.subplots(figsize=(8, 5))
sns.pointplot(data=for_plot, x='value', y='variable', orient='h', join=False, scale=0.7)
plt.title("Average percent change in mobility \n All years and states (95% CI)")
plt.ylabel("POI category")
plt.xlabel("Heat wave mobility change (%)")


plt.tight_layout()
plt.savefig(data_path + 'results/imgs/avg_agg_point.png', dpi=300)

# %%
df = pd.DataFrame()
df = df.append(pd.DataFrame(mobility_heat['retail_difference'].describe()).transpose())
df = df.append(pd.DataFrame(mobility_heat['grocery_pharmacy_difference'].describe()).transpose())
df = df.append(pd.DataFrame(mobility_heat['parks_difference'].describe()).transpose())
df = df.append(pd.DataFrame(mobility_heat['transit_difference'].describe()).transpose())
df = df.append(pd.DataFrame(mobility_heat['workplaces_difference'].describe()).transpose())
df = df.append(pd.DataFrame(mobility_heat['residential_difference'].describe()).transpose())
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_52977/1313774308.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(mobility_heat['retail_difference'].describe()).transpose())
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_52977/1313774308.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(mobility_heat['grocery_pharmacy_difference'].describe()).transpose())
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_52977/1313774308.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(mobility_heat['parks_difference'].describe()).transpose())
# ...

# %%
df.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_abea3_row0_col0, #T_abea3_row3_col4 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_abea3_row0_col1 {
#   background-color: #920a13;
#   color: #f1f1f1;
# }
# #T_abea3_row0_col2, #T_abea3_row0_col7 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_abea3_row0_col3 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_abea3_row0_col4 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_abea3_row0_col5, #T_abea3_row4_col5, #T_abea3_row5_col5 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_abea3_row0_col6, #T_abea3_row3_col6 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_abea3_row1_col0 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_abea3_row1_col1, #T_abea3_row1_col5, #T_abea3_row2_col2, #T_abea3_row2_col6, #T_abea3_row2_col7, #T_abea3_row4_col0, #T_abea3_row5_col3, #T_abea3_row5_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_abea3_row1_col2 {
# ...

# %% [markdown]
# ### Test difference in means and temperature-mobility relationship

# %%
for category in ['retail', 'grocery_pharmacy', 'parks', 'transit', 'workplaces', 'residential']:
    display(Markdown(f"\n {category} \n"))
    temp_test = mobility_heat.dropna(subset=[f'{category}_heat', f'{category}_control'])
    ttest = ttest_ind(temp_test[f'{category}_heat'].values, temp_test[f'{category}_control'].values)
    display(Markdown(f"Independent T-Test Value (p-value): {ttest[0]} ({ttest[1]})"))
    pearson = pearsonr(x=temp_test['temperature_2m'], y=temp_test[f'{category}_difference'])
    display(Markdown(f"Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): {pearson[0]}, ({pearson[1]})"))
    print(' \n ')
# Out:
#  retail
# Independent T-Test Value (p-value): 1.8602121382372958 (0.06288304894204126)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.144049215614838, (4.180665673183026e-26)
#  grocery_pharmacy
# Independent T-Test Value (p-value): 3.3651170074857535 (0.0007682275163035047)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.17880447610088815, (1.6734296401222788e-34)
#  parks
# Independent T-Test Value (p-value): -2.2100190965084616 (0.027142757560480953)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.1658431983192574, (2.485943095299149e-19)
#  transit
# Independent T-Test Value (p-value): -0.8724404827834227 (0.3829981937146565)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.07179325507790206, (2.2195154648726893e-05)
#  workplaces
# Independent T-Test Value (p-value): -4.02695647467462 (5.6849932134961344e-05)
# ...

# %% [markdown]
#  ## State-Level Analysis Combining All Years

# %%
sns.catplot(data=for_plot, x='state', y='value', col='variable', col_wrap=3, orient='v',
            kind='violin', sharey=False, legend=True, sharex=False)
plt.plot()
# Out:
# /Users/shivyucel/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/seaborn/categorical.py:3201: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)
# []

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.pointplot(data=for_plot, x='value', y='variable', hue='state', orient='h',  join=False, errorbar=None, ax=ax, scale=0.7, dodge=0.5)
plt.title("Average percent change in mobility \n Separated by State")
plt.ylabel("POI category")
plt.xlabel("Heat wave mobility change (%)")


plt.tight_layout()
plt.savefig(data_path + 'results/imgs/avg_state_point.png', dpi=300)

# %%
mobility_heat.groupby(['state'])['retail_difference'].describe()
# Out:
#                    count      mean        std   min  25%  50%   75%   max
# state
# British Columbia   953.0  5.377754  10.579233 -38.0 -1.0  3.0  10.0  61.0
# California        2088.0 -0.483716   7.070304 -81.0 -3.0 -1.0   2.0  57.0
# Oregon            1098.0 -0.530055   9.403810 -50.0 -4.0 -1.0   2.0  76.0
# Washington        1190.0  0.984874   6.772385 -34.0 -2.0  0.0   3.0  43.0

# %%
mobility_heat.groupby(['state'])['grocery_pharmacy_difference'].describe()
# Out:
#                    count      mean        std   min  25%  50%   75%   max
# state
# British Columbia   869.0  5.860759  10.779747 -19.0 -1.0  3.0  11.0  58.0
# California        1953.0 -0.311316   6.098102 -44.0 -3.0  0.0   3.0  39.0
# Oregon             864.0  0.917824   7.479378 -44.0 -3.0  0.0   4.0  83.0
# Washington         935.0  1.156150   6.192418 -39.0 -2.0  1.0   4.0  44.0

# %%
mobility_heat.groupby(['state'])['parks_difference'].describe()
# Out:
#                    count       mean        std    min    25%   50%    75%  \
# state
# British Columbia   254.0  20.929134  43.668837 -103.0  -3.00  12.5  40.50
# California        1571.0  -8.216423  25.635122 -200.0 -17.00  -7.0   1.00
# Oregon             514.0  -5.671206  42.900570 -173.0 -25.75 -13.0   5.75
# Washington         561.0  -2.677362  34.159568 -257.0 -20.00  -6.0  15.00
#
#                     max
# state
# British Columbia  268.0
# California        165.0
# Oregon            320.0
# Washington        144.0

# %%
mobility_heat.groupby(['state'])['transit_difference'].describe()
# Out:
#                    count      mean        std   min  25%  50%  75%   max
# state
# British Columbia   363.0  1.663912  10.641963 -86.0 -2.0  2.0  7.0  51.0
# California        1597.0 -1.060113   9.623170 -98.0 -5.0 -1.0  2.0  54.0
# Oregon             735.0 -2.221769  11.589296 -65.0 -7.0 -2.0  3.0  68.0
# Washington         789.0 -0.346008  10.847029 -39.0 -5.0 -1.0  3.0  83.0

# %%
mobility_heat.groupby(['state'])['workplaces_difference'].describe()
# Out:
#                    count      mean        std   min  25%  50%  75%   max
# state
# British Columbia  1003.0 -4.880359  10.446119 -54.0 -6.0 -2.0  0.0  13.0
# California        2265.0  0.161589  11.482104 -54.0 -2.0  0.0  2.0  50.0
# Oregon            1310.0 -0.201527   6.995185 -51.0 -2.0 -1.0  1.0  48.0
# Washington        1445.0 -0.746713   4.015146 -37.0 -2.0  0.0  1.0  40.0

# %%
mobility_heat.groupby(['state'])['residential_difference'].describe()
# Out:
#                    count      mean       std   min  25%  50%  75%   max
# state
# British Columbia   898.0  0.122494  2.180926  -6.0 -1.0  0.0  1.0  10.0
# California        1941.0  0.093766  2.465529 -12.0 -1.0  0.0  1.0  14.0
# Oregon             985.0  0.085279  1.759075  -8.0 -1.0  0.0  1.0   8.0
# Washington        1175.0  0.024681  1.671049  -6.0 -1.0  0.0  1.0   7.0

# %% [markdown]
# ### Test difference in means and temperature-mobility relationship

# %%
for state in ['Oregon', 'Washington', 'California', 'British Columbia']:
    temp = mobility_heat[(mobility_heat['state'] == state)]
    for category in ['retail', 'grocery_pharmacy', 'parks', 'transit', 'workplaces', 'residential']:
        display(Markdown(f"\n {state}-{category} \n "))
        temp_test = temp.dropna(subset=[f'{category}_heat', f'{category}_control'])
        ttest = ttest_ind(temp_test[f'{category}_heat'].values, temp_test[f'{category}_control'].values)
        display(Markdown(f"Independent T-Test Value (p-value): {ttest[0]} ({ttest[1]})"))
        pearson = pearsonr(x=temp_test['temperature_2m'], y=temp_test[f'{category}_difference'])
        display(Markdown(f"Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): {pearson[0]}, ({pearson[1]})"))
        print(' \n ')
# Out:
#  Oregon-retail
# Independent T-Test Value (p-value): -0.5036608965801125 (0.6145502565947573)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.12089003838265402, (5.9195107934080623e-05)
#  Oregon-grocery_pharmacy
# Independent T-Test Value (p-value): 1.250787844862092 (0.2111814153958211)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.04017032278790695, (0.23818790812216398)
#  Oregon-parks
# Independent T-Test Value (p-value): -1.5511625934060027 (0.12117111206547584)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): 0.02792731695875639, (0.5275582284865273)
#  Oregon-transit
# Independent T-Test Value (p-value): -0.9454364165067232 (0.3445917013829888)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.06682829855095816, (0.0701849654655839)
#  Oregon-workplaces
# Independent T-Test Value (p-value): -0.4449612384267027 (0.6563845509588414)
# ...

# %% [markdown]
# ## State-Level Analysis Differentiating by Years

# %%
for_plot['Mobility Percent Change'] = for_plot['value']

# %%
sns.catplot(data=for_plot, x='year', y='Mobility Percent Change', hue='state', col='variable', col_wrap=3, orient='v',
            kind='point', sharey=False, legend=True, sharex=False, join=True, errorbar=None, margin_titles=True, dodge=0.3)


plt.plot()
plt.savefig(data_path + 'results/imgs/state_year_split.png', dpi=300)

# %%
mobility_heat.groupby(['year', 'state'])['retail_difference'].describe()
# Out:
#                        count      mean        std   min  25%  50%    75%   max
# year state
# 2020 British Columbia  130.0  3.400000   6.165168 -21.0 -1.0  3.0   6.75  28.0
#      California        637.0 -0.252747   5.173759 -27.0 -3.0 -1.0   1.00  23.0
#      Oregon            185.0 -0.124324   6.518427 -17.0 -4.0 -1.0   2.00  29.0
#      Washington        222.0 -0.265766   5.170102 -11.0 -3.0 -1.0   1.00  36.0
# 2021 British Columbia  479.0  7.217119  12.679623 -24.0 -1.0  4.0  13.00  61.0
#      California        673.0 -1.915305   7.846952 -73.0 -5.0 -1.0   1.00  25.0
#      Oregon            479.0 -1.158664  11.021465 -50.0 -5.0 -2.0   2.00  76.0
#      Washington        499.0  0.601202   6.961979 -23.0 -3.0  0.0   3.00  43.0
# 2022 British Columbia  344.0  3.563953   7.923577 -38.0 -1.0  3.0   7.00  31.0
#      California        778.0  0.565553   7.495615 -81.0 -2.0  0.0   3.00  57.0
#      Oregon            434.0 -0.009217   8.432583 -48.0 -4.0  0.0   3.00  32.0
# ...

# %%
mobility_heat.groupby(['year', 'state'])['grocery_pharmacy_difference'].describe()
# Out:
#                        count      mean        std   min   25%  50%    75%  \
# year state
# 2020 British Columbia  116.0  6.129310   9.227115 -19.0  1.00  4.0   9.00
#      California        594.0 -0.324916   4.501881 -19.0 -3.00 -1.0   2.00
#      Oregon            146.0  0.287671   5.854511 -12.0 -4.00 -1.0   3.75
#      Washington        177.0  0.299435   5.780615 -16.0 -3.00  0.0   3.00
# 2021 British Columbia  436.0  7.110092  12.329081 -19.0 -1.25  4.0  13.00
#      California        626.0 -1.867412   6.476048 -44.0 -5.00 -1.0   2.00
#      Oregon            380.0  0.865789   8.591300 -44.0 -3.00  0.0   3.00
#      Washington        372.0  0.680108   6.820164 -17.0 -3.00  0.0   3.00
# 2022 British Columbia  317.0  4.044164   8.571254 -17.0 -1.00  3.0   7.00
#      California        733.0  1.028649   6.562686 -38.0 -2.00  1.0   4.00
#      Oregon            338.0  1.248521   6.724137 -28.0 -2.00  1.0   4.00
# ...

# %%
mobility_heat.groupby(['year', 'state'])['parks_difference'].describe()
# Out:
#                        count       mean        std    min    25%   50%    75%  \
# year state
# 2020 British Columbia   45.0  21.733333  36.181613  -41.0  -2.00  13.0  32.00
#      California        455.0  -5.305495  18.562464  -64.0 -15.00  -6.0   3.00
#      Oregon             72.0  -0.777778  31.874853  -46.0 -19.00  -8.5   5.25
#      Washington         83.0   2.024096  28.521270  -72.0 -16.50  -3.0  26.50
# 2021 British Columbia  118.0  20.008475  45.394283 -103.0  -3.75  11.0  41.25
#      California        525.0 -11.022857  22.687881 -128.0 -18.00  -7.0   0.00
#      Oregon            226.0  -3.256637  50.309757 -105.0 -29.75 -13.0   7.00
#      Washington        223.0  -9.179372  40.288533 -257.0 -30.50 -12.0   6.00
# 2022 British Columbia   91.0  21.725275  45.163915  -93.0  -3.00  15.0  41.50
#      California        591.0  -7.964467  31.824632 -200.0 -17.50  -7.0   2.00
#      Oregon            216.0  -9.828704  37.088998 -173.0 -25.00 -13.0   4.00
# ...

# %%
mobility_heat.groupby(['year', 'state'])['transit_difference'].describe()
# Out:
#                        count      mean        std   min   25%  50%   75%   max
# year state
# 2020 British Columbia   57.0  1.280702   5.377713 -12.0 -1.00  1.0  4.00  16.0
#      California        453.0 -1.677704   5.861028 -44.0 -4.00 -1.0  1.00  17.0
#      Oregon            111.0 -1.657658   7.157317 -29.0 -5.00 -2.0  1.50  19.0
#      Washington        141.0 -0.567376   6.702137 -25.0 -4.00 -1.0  3.00  19.0
# 2021 British Columbia  172.0  2.209302  11.007298 -46.0 -1.25  2.5  7.25  51.0
#      California        536.0 -1.598881  10.994541 -64.0 -5.00 -1.0  2.00  49.0
#      Oregon            342.0 -2.061404  13.208869 -65.0 -8.00 -2.0  3.75  68.0
#      Washington        321.0 -0.800623  12.006149 -39.0 -6.00 -2.0  3.00  83.0
# 2022 British Columbia  134.0  1.126866  11.813349 -86.0 -2.00  1.5  5.75  25.0
#      California        608.0 -0.125000  10.485771 -98.0 -4.00  0.0  4.00  54.0
#      Oregon            282.0 -2.638298  10.895999 -56.0 -6.00 -1.5  3.00  22.0
# ...

# %%
mobility_heat.groupby(['year', 'state'])['workplaces_difference'].describe()
# Out:
#                        count      mean        std   min   25%  50%  75%   max
# year state
# 2020 British Columbia  143.0 -2.125874   4.129705 -43.0  -3.0 -2.0 -1.0   5.0
#      California        672.0 -1.915179   8.677546 -43.0  -2.0  0.0  1.0  19.0
#      Oregon            226.0 -1.792035   5.365414 -39.0  -2.0 -1.0  0.0   7.0
#      Washington        286.0 -0.692308   2.152863 -10.0  -2.0 -1.0  0.0  10.0
# 2021 British Columbia  494.0 -6.726721  11.025152 -54.0 -10.0 -3.0  0.0  13.0
#      California        749.0  1.353805   8.136144 -43.0  -2.0  0.0  2.0  38.0
#      Oregon            584.0 -1.294521   6.320668 -51.0  -3.0 -1.0  1.0  36.0
#      Washington        601.0 -2.008319   4.580567 -37.0  -3.0 -1.0  0.0  11.0
# 2022 British Columbia  366.0 -3.464481  10.915496 -54.0  -4.0 -1.0  2.0   9.0
#      California        844.0  0.757109  15.177057 -54.0  -1.0  1.0  3.0  50.0
#      Oregon            500.0  1.794000   7.884916 -40.0  -1.0  0.0  3.0  48.0
# ...

# %%
mobility_heat.groupby(['year', 'state'])['residential_difference'].describe()
# Out:
#                        count      mean       std   min  25%  50%  75%   max
# year state
# 2020 British Columbia  115.0 -0.321739  0.996026  -4.0 -1.0  0.0  0.0   2.0
#      California        619.0  0.329564  2.019632 -12.0 -1.0  0.0  1.0  10.0
#      Oregon            178.0  0.185393  1.342234  -2.0  0.0  0.0  0.0   6.0
#      Washington        228.0  0.026316  0.864987  -2.0  0.0  0.0  0.0   3.0
# 2021 British Columbia  450.0  0.148889  2.548865  -6.0 -1.0  0.0  1.0  10.0
#      California        607.0 -0.204283  2.039490 -12.0 -1.0  0.0  1.0  11.0
#      Oregon            421.0  0.361045  1.671271  -8.0  0.0  1.0  1.0   8.0
#      Washington        477.0  0.475891  1.531856  -6.0  0.0  1.0  1.0   7.0
# 2022 British Columbia  333.0  0.240240  1.908116  -5.0 -1.0  0.0  1.0   7.0
#      California        715.0  0.142657  3.054466 -11.0 -2.0  0.0  1.0  14.0
#      Oregon            386.0 -0.261658  1.955726  -8.0 -2.0  0.0  1.0   5.0
# ...

# %% [markdown]
# ### Test difference in means and temperature-mobility relationship

# %%
df = pd.DataFrame()

# %%
dic = {}
for year in [2020, 2021, 2022]:
    print(year)
    dic[year] = {}
    for state in ['Oregon', 'Washington', 'California', 'British Columbia']:
        dic[year][state] = {}
        temp = mobility_heat[(mobility_heat['state'] == state) & (mobility_heat['year'] == year)]
        for category in ['retail', 'grocery_pharmacy', 'parks', 'transit', 'workplaces', 'residential']:
            dic[year][state][category] = {}
            display(Markdown(f"\n {state} - {category} \n"))
            temp_test = temp.dropna(subset=[f'{category}_heat', f'{category}_control'])
            ttest = ttest_ind(temp_test[f'{category}_heat'].values, temp_test[f'{category}_control'].values)
            display(Markdown(f"Independent T-Test Value (p-value): {ttest[0]} ({ttest[1]})"))
            pearson = pearsonr(x=temp_test['temperature_2m'], y=temp_test[f'{category}_difference'])
            display(Markdown(f"Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): {pearson[0]}, ({pearson[1]})"))
            dic[year][state][category]['p-value'] = ttest[1]
            dic[year][state][category]['pearson'] = f"{pearson[0]}, ({pearson[1]})"
            print(' \n ')
# Out:
# 2020
#  Oregon - retail
# Independent T-Test Value (p-value): -0.04900380605889222 (0.9609428476252037)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.3063369200310099, (2.2272562036120402e-05)
#  Oregon - grocery_pharmacy
# Independent T-Test Value (p-value): 0.16281414702395142 (0.8707781628935468)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.30109052664283803, (0.00022171872180111292)
#  Oregon - parks
# Independent T-Test Value (p-value): -0.07743387129098481 (0.9383873970405621)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.028810786411909636, (0.8101450307138831)
#  Oregon - transit
# Independent T-Test Value (p-value): -0.35284490132085156 (0.724542544729667)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.11019577256182167, (0.24958729033235239)
#  Oregon - workplaces
# ...

# %%
dic
# Out:
# {2020: {'Oregon': {'retail': {'p-value': 0.9609428476252037,
#     'pearson': '-0.3063369200310099, (2.2272562036120402e-05)'},
#    'grocery_pharmacy': {'p-value': 0.8707781628935468,
#     'pearson': '-0.30109052664283803, (0.00022171872180111292)'},
#    'parks': {'p-value': 0.9383873970405621,
#     'pearson': '-0.028810786411909636, (0.8101450307138831)'},
#    'transit': {'p-value': 0.724542544729667,
#     'pearson': '-0.11019577256182167, (0.24958729033235239)'},
#    'workplaces': {'p-value': 0.11197171576665688,
#     'pearson': '-0.0060085666206021095, (0.9284235063258458)'},
#    'residential': {'p-value': 0.6629128038636836,
#     'pearson': '0.030181036308153844, (0.6892158143857439)'}},
#   'Washington': {'retail': {'p-value': 0.8838445904995271,
#     'pearson': '-0.09468375306953004, (0.1597381991572166)'},
#    'grocery_pharmacy': {'p-value': 0.8581829466564616,
#     'pearson': '-0.3198528280546969, (1.426305968282349e-05)'},
# ...

# %% [markdown]
# ### Check Hottest Heat Wave Day Differences

# %%
mobility_heat['heat_ranking'] = mobility_heat.groupby('state')['temperature_2m'].apply(lambda x: x.rank(pct=True))
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_40949/3820105249.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   mobility_heat['heat_ranking'] = mobility_heat.groupby('state')['temperature_2m'].apply(lambda x: x.rank(pct=True))

# %%
high_heat = mobility_heat[mobility_heat['heat_ranking'] >= 0.8]

# %%
high_heat_plot = high_heat.melt(id_vars=['county', 'state', 'year'], value_vars=['retail_difference', 'grocery_pharmacy_difference', 'parks_difference', 'transit_difference', 'workplaces_difference', 'residential_difference'])

# %%
sns.pointplot(data=high_heat_plot, x='value', y='variable', hue='state', orient='h', join=False, scale=0.7, errorbar=None)
plt.plot()
# Out:
# []

# %%
sns.catplot(data=high_heat_plot, x='year', y='value', hue='state', col='variable', col_wrap=3, orient='v',
            kind='point', sharey=False, legend=True, sharex=False, join=False, errorbar=None)


plt.plot()
# Out:
# []

# %%
high_heat.groupby('state')['retail_difference'].describe()
# Out:
#                   count      mean        std   min  25%  50%   75%   max
# state
# British Columbia  188.0  8.473404  11.006286 -14.0  1.0  7.0  14.0  49.0
# California        455.0 -0.872527   7.189476 -57.0 -4.0 -1.0   1.0  57.0
# Oregon            186.0 -1.161290  12.419941 -33.0 -6.0 -2.0   1.0  76.0
# Washington        240.0  0.250000   6.596246 -20.0 -3.0  0.0   3.0  43.0

# %%
high_heat.groupby('state')['grocery_pharmacy_difference'].describe()
# Out:
#                   count       mean        std   min  25%  50%   75%   max
# state
# British Columbia  165.0  10.290909  12.362916 -16.0  1.0  9.0  17.0  58.0
# California        397.0  -1.083123   5.379126 -27.0 -3.0 -1.0   2.0  15.0
# Oregon            154.0   0.837662  10.778501 -19.0 -4.0 -1.0   3.0  83.0
# Washington        202.0  -0.306931   6.464203 -17.0 -4.0 -1.0   3.0  44.0

# %%
high_heat.groupby('state')['parks_difference'].describe()
# Out:
#                   count       mean        std    min   25%   50%    75%    max
# state
# British Columbia   57.0  32.491228  51.259885  -93.0  -3.0  29.0  62.00  163.0
# California        381.0 -10.073491  20.254690 -128.0 -19.0  -9.0  -1.00  136.0
# Oregon             80.0  10.625000  63.495515  -54.0 -25.0  -7.5  23.25  320.0
# Washington         88.0  -4.250000  49.065110 -257.0 -25.0  -8.0  15.75  144.0

# %%
high_heat.groupby('state')['transit_difference'].describe()
# Out:
#                   count      mean        std   min  25%  50%  75%   max
# state
# British Columbia   73.0  0.315068  11.447800 -37.0 -5.0  0.0  7.0  35.0
# California        363.0 -0.710744   9.769813 -35.0 -5.0 -1.0  2.0  49.0
# Oregon            189.0 -2.650794  13.661359 -46.0 -8.0 -3.0  4.0  68.0
# Washington        188.0 -1.686170  12.016140 -36.0 -8.0 -2.0  3.0  78.0

# %%
high_heat.groupby('state')['workplaces_difference'].describe()
# Out:
#                   count      mean        std   min   25%  50%  75%   max
# state
# British Columbia  194.0 -9.350515  12.947516 -54.0 -12.0 -5.0 -2.0  10.0
# California        457.0 -2.183807  13.555163 -54.0  -3.0 -1.0  2.0  43.0
# Oregon            250.0 -1.592000   5.182758 -33.0  -4.0 -1.5  1.0  16.0
# Washington        293.0 -2.477816   4.441055 -16.0  -4.0 -1.0  0.0   8.0

# %%
high_heat.groupby('state')['residential_difference'].describe()
# Out:
#                   count      mean       std  min  25%  50%  75%   max
# state
# British Columbia  175.0  0.068571  2.861935 -6.0 -1.0  0.0  1.0   8.0
# California        395.0  0.721519  3.001424 -9.0  0.0  0.0  1.0  12.0
# Oregon            155.0 -0.316129  1.963150 -4.0 -2.0  0.0  1.0   7.0
# Washington        236.0  0.338983  1.927275 -6.0 -1.0  1.0  2.0   5.0

# %%
high_heat = mobility_heat[mobility_heat['heat_ranking'] >= 0.8]

# %%
for year in [2020, 2021, 2022]:
    print(year)
    for state in ['Oregon', 'Washington', 'California', 'British Columbia']:
        temp = high_heat[(high_heat['state'] == state) & (high_heat['year'] == year)]
        for category in ['retail', 'grocery_pharmacy', 'parks', 'transit', 'workplaces', 'residential']:
            display(Markdown(f"\n {state} - {category} \n"))
            temp_test = mobility_heat.dropna(subset=[f'{category}_heat', f'{category}_control'])
            ttest = ttest_ind(temp_test[f'{category}_heat'].values, temp_test[f'{category}_control'].values)
            display(Markdown(f"Independent T-Test Value (p-value): {ttest[0]} ({ttest[1]})"))
            pearson = pearsonr(x=temp_test['temperature_2m'], y=temp_test[f'{category}_difference'])
            display(Markdown(f"Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): {pearson[0]}, ({pearson[1]})"))
            print(' \n ')
# Out:
# 2020
#  Oregon - retail
# Independent T-Test Value (p-value): 1.8371862666988565 (0.06621045931963077)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.14537236184729602, (2.3231031407642696e-26)
#  Oregon - grocery_pharmacy
# Independent T-Test Value (p-value): 3.3390217223423697 (0.0008440970213462957)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.1807849305472665, (6.208860236877066e-35)
#  Oregon - parks
# Independent T-Test Value (p-value): -2.2938048319704385 (0.021837845144337537)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.1621904049978901, (2.703349098108677e-18)
#  Oregon - transit
# Independent T-Test Value (p-value): -0.8812801540588936 (0.37819699046918953)
# Pearson Correlation of Heat Wave Temperature and Mobility Change (p-value): -0.07118771906051263, (2.919448112592561e-05)
#  Oregon - workplaces
# ...
