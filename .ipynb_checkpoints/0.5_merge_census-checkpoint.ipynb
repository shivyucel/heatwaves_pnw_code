# %%
import pandas as pd
import geopandas as gpd
data_path = '/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/'

# %%
#get BC regional district average incomes and get deciles
#from https://www12.statcan.gc.ca/census-recensement/2021/dp-pd/prof/details/download-telecharger.cfm?Lang=E

# %%
BC_data = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/census/Canada/BC_income_v2.CSV', encoding='latin-1')
mob_vars = pd.read_csv(data_path + 'mobility_heat/mobility_heat_vars_clean_90.csv')

# %%
lst = [x for x in BC_data['GEO_NAME'] if 'Regional district' in x]
BC_data = BC_data[BC_data['GEO_NAME'].isin(lst)]


household_income = BC_data[BC_data['CHARACTERISTIC_NAME'] == '  Median total income of household in 2020 ($)']
household_income['median_income'] = household_income['C1_COUNT_TOTAL']



population = BC_data[BC_data['CHARACTERISTIC_NAME'] == 'Population, 2021']
population['population'] = population['C1_COUNT_TOTAL']

age = BC_data[BC_data['CHARACTERISTIC_NAME'] == '  65 years and over']
age['65_and_over'] = age['C1_COUNT_TOTAL']

nonwhite = BC_data[BC_data['CHARACTERISTIC_NAME'] == '  Total visible minority population']
nonwhite['nonwhite_pop'] = nonwhite['C1_COUNT_TOTAL']
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97576/620747723.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   household_income['median_income'] = household_income['C1_COUNT_TOTAL']
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97576/620747723.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population['population'] = population['C1_COUNT_TOTAL']
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97576/620747723.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age['65_and_over'] = age['C1_COUNT_TOTAL']
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97576/620747723.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonwhite['nonwhite_pop'] = nonwhite['C1_COUNT_TOTAL']

# %% [markdown]
# # Population Density

# %%
import pandas as pd
us_areas = pd.read_csv(data_path + 'census/US/pop_dens.csv')
ca_areas = pd.read_html("https://en.wikipedia.org/wiki/List_of_regional_districts_of_British_Columbia")

us_areas = us_areas[['NAME', 'State', 'B01001_calc_PopDensity']]

ca_areas = ca_areas[1][['Regional district', 'Density (per km2)']]
ca_areas.replace({'–': '-'}, regex=True, inplace=True)
ca_areas.replace('Metro Vancouver', 'Greater Vancouver', inplace=True)

us_areas.columns = ['county', 'state', 'popdens']

ca_areas.columns = ['county', 'popdens']
ca_areas['state'] = 'British Columbia'

pop_dens = pd.concat([us_areas, ca_areas])

pop_dens['location'] = pop_dens['county'] + ', ' + pop_dens['state']

# %%
pop_dens = pop_dens[pop_dens['state'].isin(['British Columbia', 'California', 'Oregon', 'Washington'])]

# %%
pop_dens['popdens_dec'] = pop_dens.groupby('state')['popdens'].transform(lambda x: pd.qcut(x, 10, labels=False))
pop_dens['popdens_dec'] += 1

# %%
pop_dens
# Out:
#                 county             state     popdens  \
# 186     Alameda County        California  860.757075
# 187      Alpine County        California    0.599281
# 188      Amador County        California   24.565345
# 189       Butte County        California   53.575159
# 190   Calaveras County        California   17.122606
# ..                 ...               ...         ...
# 24   Squamish-Lillooet  British Columbia    2.600000
# 25   Stikine Region[a]  British Columbia    0.010000
# 26          Strathcona  British Columbia    2.400000
# 27      Sunshine Coast  British Columbia    7.900000
# 28     Thompson-Nicola  British Columbia    3.000000
#
#                                 location  popdens_dec
# 186           Alameda County, California           10
# 187            Alpine County, California            1
# 188            Amador County, California            4
# 189             Butte County, California            6
# 190         Calaveras County, California            4
# ..                                   ...          ...
# 24   Squamish-Lillooet, British Columbia            5
# 25   Stikine Region[a], British Columbia            1
# 26          Strathcona, British Columbia            5
# 27      Sunshine Coast, British Columbia            7
# 28     Thompson-Nicola, British Columbia            6
#
# [162 rows x 5 columns]

# %% [markdown]
# # Age, income, race

# %%
age = age.groupby('DGUID').first().reset_index()

# %%
income_pop = household_income.merge(population[['DGUID', 'CHARACTERISTIC_NAME', 'population']], on='DGUID')

# %%
income_pop_age = income_pop.merge(age[['DGUID', 'CHARACTERISTIC_NAME', '65_and_over']], on='DGUID')

# %%
can_total = income_pop_age.merge(nonwhite[['DGUID', 'CHARACTERISTIC_NAME', 'nonwhite_pop']], on='DGUID')
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97576/2573391190.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'CHARACTERISTIC_NAME_x'} in the result is deprecated and will raise a MergeError in a future version.
#   can_total = income_pop_age.merge(nonwhite[['DGUID', 'CHARACTERISTIC_NAME', 'nonwhite_pop']], on='DGUID')

# %%
can_total['district'] = [x.split(',')[0] for x in can_total['GEO_NAME']]

# %%
can_total['propor_over_65'] = can_total['65_and_over'] / can_total['population']

# %%
can_total['non_white_propor'] = can_total['nonwhite_pop'] / can_total['population']

# %%
can_total['income_dec'] = pd.qcut(can_total['median_income'],10,labels=False)
can_total['income_dec'] += 1

# %%
can_total['over65_dec'] = pd.qcut(can_total['propor_over_65'],10,labels=False)
can_total['over65_dec'] += 1

# %%
can_total['nonwhite_dec'] = pd.qcut(can_total['non_white_propor'],10,labels=False)
can_total['nonwhite_dec'] += 1

# %%
can_total
# Out:
#     CENSUS_YEAR          DGUID  ALT_GEO_CODE        GEO_LEVEL  \
# 0          2021  2021A00035901          5901  Census division
# 1          2021  2021A00035903          5903  Census division
# 2          2021  2021A00035905          5905  Census division
# 3          2021  2021A00035907          5907  Census division
# 4          2021  2021A00035909          5909  Census division
# 5          2021  2021A00035915          5915  Census division
# 6          2021  2021A00035917          5917  Census division
# 7          2021  2021A00035919          5919  Census division
# 8          2021  2021A00035921          5921  Census division
# 9          2021  2021A00035923          5923  Census division
# 10         2021  2021A00035924          5924  Census division
# 11         2021  2021A00035926          5926  Census division
# 12         2021  2021A00035927          5927  Census division
# 13         2021  2021A00035929          5929  Census division
# 14         2021  2021A00035931          5931  Census division
# 15         2021  2021A00035933          5933  Census division
# 16         2021  2021A00035935          5935  Census division
# 17         2021  2021A00035937          5937  Census division
# 18         2021  2021A00035939          5939  Census division
# 19         2021  2021A00035941          5941  Census division
# 20         2021  2021A00035943          5943  Census division
# 21         2021  2021A00035945          5945  Census division
# 22         2021  2021A00035947          5947  Census division
# 23         2021  2021A00035949          5949  Census division
# 24         2021  2021A00035951          5951  Census division
# 25         2021  2021A00035953          5953  Census division
# 26         2021  2021A00035955          5955  Census division
# 27         2021  2021A00035959          5959  Census division
#
#                                           GEO_NAME  TNR_SF  TNR_LF  \
# 0            East Kootenay, Regional district (RD)     5.8     7.9
# 1         Central Kootenay, Regional district (RD)     3.5     5.7
# 2        Kootenay Boundary, Regional district (RD)     6.2     8.2
# 3     Okanagan-Similkameen, Regional district (RD)     3.6     5.9
# 4            Fraser Valley, Regional district (RD)     3.2     5.0
# 5        Greater Vancouver, Regional district (RD)     3.0     3.9
# 6                  Capital, Regional district (RD)     3.1     4.3
# 7          Cowichan Valley, Regional district (RD)     3.2     4.6
# 8                  Nanaimo, Regional district (RD)     2.7     3.8
# 9        Alberni-Clayoquot, Regional district (RD)     4.6     6.2
# 10              Strathcona, Regional district (RD)     3.3     4.5
# 11            Comox Valley, Regional district (RD)     2.1     2.9
# 12            Powell River, Regional district (RD)     4.5     6.8
# 13          Sunshine Coast, Regional district (RD)     5.2     7.1
# 14       Squamish-Lillooet, Regional district (RD)    10.7    17.1
# 15         Thompson-Nicola, Regional district (RD)     5.3     7.5
# 16        Central Okanagan, Regional district (RD)     4.2     5.8
# 17          North Okanagan, Regional district (RD)     3.7     5.1
# 18        Columbia-Shuswap, Regional district (RD)     5.8     7.8
# 19                 Cariboo, Regional district (RD)     4.6     6.1
# 20        Mount Waddington, Regional district (RD)     6.0     9.4
# 21           Central Coast, Regional district (RD)    11.7    13.8
# 22  Skeena-Queen Charlotte, Regional district (RD)     5.6    10.3
# 23         Kitimat-Stikine, Regional district (RD)     5.8     7.6
# 24         Bulkley-Nechako, Regional district (RD)     6.2    11.9
# 25      Fraser-Fort George, Regional district (RD)     2.9     5.8
# 26             Peace River, Regional district (RD)     6.7    11.1
# 27        Northern Rockies, Regional district (RD)    12.4    18.0
#
#     DATA_QUALITY_FLAG  CHARACTERISTIC_ID  \
# 0                   0                243
# 1                   0                243
# 2                   0                243
# 3                   0                243
# 4               20000                243
# 5               20000                243
# 6                   0                243
# 7                   0                243
# 8                   0                243
# 9               20000                243
# 10                  0                243
# 11                  0                243
# 12                  0                243
# 13                  0                243
# 14               1010                243
# 15              20000                243
# 16                  0                243
# 17                  0                243
# 18              20000                243
# 19              20000                243
# 20                  0                243
# 21               1010                243
# 22              20010                243
# 23                  0                243
# 24              20010                243
# 25                  0                243
# 26                 10                243
# 27               1010                243
#
#                              CHARACTERISTIC_NAME_x  ...  \
# 0     Median total income of household in 2020 ($)  ...
# 1     Median total income of household in 2020 ($)  ...
# 2     Median total income of household in 2020 ($)  ...
# 3     Median total income of household in 2020 ($)  ...
# 4     Median total income of household in 2020 ($)  ...
# 5     Median total income of household in 2020 ($)  ...
# 6     Median total income of household in 2020 ($)  ...
# 7     Median total income of household in 2020 ($)  ...
# 8     Median total income of household in 2020 ($)  ...
# 9     Median total income of household in 2020 ($)  ...
# 10    Median total income of household in 2020 ($)  ...
# 11    Median total income of household in 2020 ($)  ...
# 12    Median total income of household in 2020 ($)  ...
# 13    Median total income of household in 2020 ($)  ...
# 14    Median total income of household in 2020 ($)  ...
# 15    Median total income of household in 2020 ($)  ...
# 16    Median total income of household in 2020 ($)  ...
# 17    Median total income of household in 2020 ($)  ...
# 18    Median total income of household in 2020 ($)  ...
# 19    Median total income of household in 2020 ($)  ...
# 20    Median total income of household in 2020 ($)  ...
# 21    Median total income of household in 2020 ($)  ...
# 22    Median total income of household in 2020 ($)  ...
# 23    Median total income of household in 2020 ($)  ...
# 24    Median total income of household in 2020 ($)  ...
# 25    Median total income of household in 2020 ($)  ...
# 26    Median total income of household in 2020 ($)  ...
# 27    Median total income of household in 2020 ($)  ...
#
#     CHARACTERISTIC_NAME_x  65_and_over                CHARACTERISTIC_NAME_y  \
# 0       65 years and over      14605.0    Total visible minority population
# 1       65 years and over      16535.0    Total visible minority population
# 2       65 years and over       9195.0    Total visible minority population
# 3       65 years and over      29790.0    Total visible minority population
# 4       65 years and over      62900.0    Total visible minority population
# 5       65 years and over     460790.0    Total visible minority population
# 6       65 years and over      99645.0    Total visible minority population
# 7       65 years and over      24610.0    Total visible minority population
# 8       65 years and over      51015.0    Total visible minority population
# 9       65 years and over       8075.0    Total visible minority population
# 10      65 years and over      12870.0    Total visible minority population
# 11      65 years and over      20585.0    Total visible minority population
# 12      65 years and over       6800.0    Total visible minority population
# 13      65 years and over      10695.0    Total visible minority population
# 14      65 years and over       6115.0    Total visible minority population
# 15      65 years and over      32460.0    Total visible minority population
# 16      65 years and over      50160.0    Total visible minority population
# 17      65 years and over      24940.0    Total visible minority population
# 18      65 years and over      15145.0    Total visible minority population
# 19      65 years and over      15400.0    Total visible minority population
# 20      65 years and over       2310.0    Total visible minority population
# 21      65 years and over        615.0    Total visible minority population
# 22      65 years and over       3210.0    Total visible minority population
# 23      65 years and over       6520.0    Total visible minority population
# 24      65 years and over       6850.0    Total visible minority population
# 25      65 years and over      16205.0    Total visible minority population
# 26      65 years and over       7545.0    Total visible minority population
# 27      65 years and over        580.0    Total visible minority population
#
#     nonwhite_pop                district  propor_over_65 non_white_propor  \
# 0         3170.0           East Kootenay        0.221637         0.048106
# 1         2865.0        Central Kootenay        0.264522         0.045833
# 2         1340.0       Kootenay Boundary        0.277359         0.040420
# 3         7595.0    Okanagan-Similkameen        0.330347         0.084222
# 4        81030.0           Fraser Valley        0.194133         0.250089
# 5      1420270.0       Greater Vancouver        0.174355         0.537406
# 6        65680.0                 Capital        0.239848         0.158093
# 7         4885.0         Cowichan Valley        0.276476         0.054880
# 8        15945.0                 Nanaimo        0.299442         0.093592
# 9         1585.0       Alberni-Clayoquot        0.240894         0.047284
# 10        2345.0              Strathcona        0.267290         0.048702
# 11        4030.0            Comox Valley        0.284147         0.055628
# 12        1055.0            Powell River        0.316338         0.049079
# 13        2865.0          Sunshine Coast        0.332453         0.089058
# 14        5875.0       Squamish-Lillooet        0.121099         0.116346
# 15       12075.0         Thompson-Nicola        0.225919         0.084041
# 16       24435.0        Central Okanagan        0.225781         0.109987
# 17        5030.0          North Okanagan        0.272241         0.054907
# 18        2560.0        Columbia-Shuswap        0.265604         0.044896
# 19        2645.0                 Cariboo        0.244712         0.042030
# 20         500.0        Mount Waddington        0.213119         0.046130
# 21          60.0           Central Coast        0.171692         0.016750
# 22        2050.0  Skeena-Queen Charlotte        0.176558         0.112755
# 23        2270.0         Kitimat-Stikine        0.172532         0.060069
# 24        1610.0         Bulkley-Nechako        0.181519         0.042664
# 25        9505.0      Fraser-Fort George        0.167098         0.098011
# 26        5895.0             Peace River        0.122619         0.095804
# 27         315.0        Northern Rockies        0.129522         0.070344
#
#     income_dec over65_dec  nonwhite_dec
# 0            9          5             3
# 1            2          7             2
# 2            3          9             1
# 3            2         10             7
# 4            8          4            10
# 5           10          3            10
# 6            7          6            10
# 7            6          8             5
# 8            4          9             8
# 9            2          6             3
# 10           4          8             4
# 11           5          9             5
# 12           1         10             4
# 13           3         10             7
# 14          10          1             9
# 15           6          5             6
# 16           8          5             9
# 17           5          8             5
# 18           5          7             2
# 19           3          6             1
# 20           1          4             3
# 21           1          2             1
# 22           7          3             9
# 23           9          2             6
# 24           8          3             2
# 25           9          2             8
# 26          10          1             8
# 27           6          1             6
#
# [28 rows x 36 columns]

# %%
can_total.merge(pop_dens, left_on='district', right_on='location')
# Out:
# Empty DataFrame
# Columns: [CENSUS_YEAR, DGUID, ALT_GEO_CODE, GEO_LEVEL, GEO_NAME, TNR_SF, TNR_LF, DATA_QUALITY_FLAG, CHARACTERISTIC_ID, CHARACTERISTIC_NAME_x, CHARACTERISTIC_NOTE, C1_COUNT_TOTAL, SYMBOL, C2_COUNT_MEN+, SYMBOL.1, C3_COUNT_WOMEN+, SYMBOL.2, C10_RATE_TOTAL, SYMBOL.3, C11_RATE_MEN+, SYMBOL.4, C12_RATE_WOMEN+, SYMBOL.5, median_income, CHARACTERISTIC_NAME_y, population, CHARACTERISTIC_NAME_x, 65_and_over, CHARACTERISTIC_NAME_y, nonwhite_pop, district, propor_over_65, non_white_propor, income_dec, over65_dec, nonwhite_dec, county, state, popdens, location, popdens_dec]
# Index: []
#
# [0 rows x 41 columns]

# %%
len(mob_vars[mob_vars['state'] == 'British Columbia'])
# Out:
# 1253

# %%
bc_mob_vars = mob_vars.merge(can_total[['district', 'income_dec',  'over65_dec', 'nonwhite_dec']], left_on='county', right_on='district')

# %%
bc_mob_vars.columns
# Out:
# Index(['Unnamed: 0.2', 'index', 'Unnamed: 0.1', 'Unnamed: 0',
#        'country_region_code', 'country_region', 'state', 'county',
#        'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id',
#        'date_heat', 'retail_heat', 'grocery_pharmacy_heat', 'parks_heat',
#        'transit_heat', 'workplaces_heat', 'residential_heat', 'year',
#        'location', 'geometry', 'control_day', 'temperature_2m_heat',
#        'heat_ID_x', 'date_control', 'retail_control',
#        'grocery_pharmacy_control', 'parks_control', 'transit_control',
#        'workplaces_control', 'residential_control', 'retail_difference',
#        'grocery_pharmacy_difference', 'parks_difference', 'transit_difference',
#        'workplaces_difference', 'residential_difference', 'day_of_week',
#        'weekend', 'holiday', 'us_holiday_heat', 'us_holiday', 'C',
#        'datetime_heat', 'temperature_2m_control', 'datetime_control',
#        'temperature_2m', 'temp_diff', 'heat_ID_y', 'date',
#        'Heat Wave Duration', 'dur_ranking', 'stage', 'district', 'income_dec',
#        'over65_dec', 'nonwhite_dec'],
#       dtype='object')

# %%
mob_vars.to_csv(data_path + 'mobility_heat/mobility_heat_BC_v4.csv')

# %%
mob_vars = pd.read_csv(data_path + 'mobility_heat/mobility_heat_vars_clean_90.csv')
#mob_vars.drop(['over65_dec', 'income_dec'],axis=1, inplace=True)


us_age = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/census/US/plus65.csv', encoding='latin-1')
us_income = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/census/US/county_income.csv', encoding='latin-1')
us_race = pd.read_csv('/Users/shivyucel/Documents/projects/DPhil/Code_Data/data/census/US/county_white.csv', encoding='latin-1')

# %%
total_pop = us_age[us_age['variable'] == 'total_pop']
total_pop['total_pop'] = total_pop['estimate']
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97576/3177610766.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_pop['total_pop'] = total_pop['estimate']

# %%
us_age = us_age[us_age['variable'] != 'total_pop']

# %%
us_age = us_age.groupby('NAME').sum().reset_index()
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97576/1343126567.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   us_age = us_age.groupby('NAME').sum().reset_index()

# %%
us_age['total65plus'] = us_age['estimate']

# %%
us_age = us_age.merge(total_pop, on="NAME")

# %%
us_age['propor_over_65'] = us_age['total65plus'] / us_age['total_pop']

# %%
us_income['median_income'] = us_income['estimate']

# %%
us_income_age = us_age.merge(us_income, on='NAME')

# %%
us_income_age['state'] = [x.split(',')[-1].strip() for x in us_income_age['NAME']]

# %%
us_income_age = us_income_age[us_income_age['state'].isin(['California', 'Washington', 'Oregon'])]

# %%
us_race
# Out:
#       GEOID                              NAME    variable  estimate   moe
# 0      1001           Autauga County, Alabama  B02001_002     42150   207
# 1      1003           Baldwin County, Alabama  B02001_002    186504  1173
# 2      1005           Barbour County, Alabama  B02001_002     11587   160
# 3      1007              Bibb County, Alabama  B02001_002     17138    95
# 4      1009            Blount County, Alabama  B02001_002     54271   537
# ...     ...                               ...         ...       ...   ...
# 3216  72145  Vega Baja Municipio, Puerto Rico  B02001_002     37840  1372
# 3217  72147    Vieques Municipio, Puerto Rico  B02001_002      3775   871
# 3218  72149   Villalba Municipio, Puerto Rico  B02001_002     12216   921
# 3219  72151    Yabucoa Municipio, Puerto Rico  B02001_002      4473   845
# 3220  72153      Yauco Municipio, Puerto Rico  B02001_002     24931  1164
#
# [3221 rows x 5 columns]

# %%
us_race['white_pop'] = us_race['estimate']

# %%
us_race = us_race.merge(total_pop, on="NAME")

# %%
us_race['non_white_propor'] = 1 - (us_race['white_pop'] / us_race['total_pop'])

# %%
us_race
# Out:
#       GEOID_x                              NAME  variable_x  estimate_x  \
# 0        1001           Autauga County, Alabama  B02001_002       42150
# 1        1003           Baldwin County, Alabama  B02001_002      186504
# 2        1005           Barbour County, Alabama  B02001_002       11587
# 3        1007              Bibb County, Alabama  B02001_002       17138
# 4        1009            Blount County, Alabama  B02001_002       54271
# ...       ...                               ...         ...         ...
# 3216    72145  Vega Baja Municipio, Puerto Rico  B02001_002       37840
# 3217    72147    Vieques Municipio, Puerto Rico  B02001_002        3775
# 3218    72149   Villalba Municipio, Puerto Rico  B02001_002       12216
# 3219    72151    Yabucoa Municipio, Puerto Rico  B02001_002        4473
# 3220    72153      Yauco Municipio, Puerto Rico  B02001_002       24931
#
#       moe_x  white_pop  GEOID_y variable_y  estimate_y  moe_y  total_pop  \
# 0       207      42150     1001  total_pop       55639    NaN      55639
# 1      1173     186504     1003  total_pop      218289    NaN     218289
# 2       160      11587     1005  total_pop       25026    NaN      25026
# 3        95      17138     1007  total_pop       22374    NaN      22374
# 4       537      54271     1009  total_pop       57755    NaN      57755
# ...     ...        ...      ...        ...         ...    ...        ...
# 3216   1372      37840    72145  total_pop       51089    NaN      51089
# 3217    871       3775    72147  total_pop        8508    NaN       8508
# 3218    921      12216    72149  total_pop       21899    NaN      21899
# 3219    845       4473    72151  total_pop       32867    NaN      32867
# 3220   1164      24931    72153  total_pop       34501    NaN      34501
#
#       non_white_propor
# 0             0.242438
# 1             0.145610
# 2             0.537002
# 3             0.234022
# 4             0.060324
# ...                ...
# 3216          0.259332
# 3217          0.556300
# 3218          0.442166
# 3219          0.863906
# 3220          0.277383
#
# [3221 rows x 12 columns]

# %%
us_total = us_income_age.merge(us_race, on='NAME')

# %%
us_total['state'] = [x.split(',')[-1].strip() for x in us_total['NAME']]

# %%
us_total = us_total[us_total['state'].isin(['California', 'Washington', 'Oregon'])]

# %%
us_total = us_total[['NAME', 'propor_over_65', 'median_income', 'state', 'non_white_propor']]

# %%
us_total['income_dec'] = us_total.groupby('state')['median_income'].transform(lambda x: pd.qcut(x, 10, labels=False))
us_total['income_dec'] += 1

# %%
us_total['over65_dec'] = us_total.groupby('state')['propor_over_65'].transform(lambda x: pd.qcut(x, 10, labels=False))
us_total['over65_dec'] += 1

# %%
us_total['nonwhite_dec'] = us_total.groupby('state')['non_white_propor'].transform(lambda x: pd.qcut(x, 10, labels=False))
us_total['nonwhite_dec'] += 1

# %%
mob_vars = mob_vars.merge(us_total[['NAME', 'over65_dec', 'income_dec', 'nonwhite_dec']], left_on='location', right_on='NAME')

# %%
mob_vars['over65_dec'].min()
# Out:
# 1

# %%
mob_vars = mob_vars.append(bc_mob_vars)
# Out:
# /var/folders/8g/qp1k_1g91m5f2m9pypxwxdhh0000gn/T/ipykernel_97576/2836113146.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mob_vars = mob_vars.append(bc_mob_vars)

# %%
mob_vars
# Out:
#       Unnamed: 0.2  index  Unnamed: 0.1  Unnamed: 0 country_region_code  \
# 0                0      0             0       48495                  US
# 1                1      1             1       48496                  US
# 2                2      2             2       48533                  US
# 3                3      3             3       48534                  US
# 4                4      4             4       48566                  US
# ...            ...    ...           ...         ...                 ...
# 1248          7410   7410          7410       13380                  CA
# 1249          7411   7411          7411       13381                  CA
# 1250          7412   7412          7412       13382                  CA
# 1251          7413   7413          7413       13383                  CA
# 1252          7414   7414          7414       13384                  CA
#
#      country_region             state           county  metro_area  \
# 0     United States        California   Alameda County         NaN
# 1     United States        California   Alameda County         NaN
# 2     United States        California   Alameda County         NaN
# 3     United States        California   Alameda County         NaN
# 4     United States        California   Alameda County         NaN
# ...             ...               ...              ...         ...
# 1248         Canada  British Columbia  Thompson-Nicola         NaN
# 1249         Canada  British Columbia  Thompson-Nicola         NaN
# 1250         Canada  British Columbia  Thompson-Nicola         NaN
# 1251         Canada  British Columbia  Thompson-Nicola         NaN
# 1252         Canada  British Columbia  Thompson-Nicola         NaN
#
#       iso_3166_2_code  ...                             heat_ID_y        date  \
# 0                 NaN  ...  4aac3758-2787-4314-a67e-712b0199fdd6  2020-06-03
# 1                 NaN  ...  4aac3758-2787-4314-a67e-712b0199fdd6  2020-06-04
# 2                 NaN  ...  7fd5f2aa-6001-4a59-9eae-19cbf184048f  2020-07-11
# 3                 NaN  ...  7fd5f2aa-6001-4a59-9eae-19cbf184048f  2020-07-12
# 4                 NaN  ...  22c4245f-d449-420a-b512-00c5d81cc678  2020-08-13
# ...               ...  ...                                   ...         ...
# 1248              NaN  ...  02331be3-68ab-4060-8eb1-08d033fbe71d  2022-08-30
# 1249              NaN  ...  02331be3-68ab-4060-8eb1-08d033fbe71d  2022-08-31
# 1250              NaN  ...  02331be3-68ab-4060-8eb1-08d033fbe71d  2022-09-01
# 1251              NaN  ...  02331be3-68ab-4060-8eb1-08d033fbe71d  2022-09-02
# 1252              NaN  ...  02331be3-68ab-4060-8eb1-08d033fbe71d  2022-09-03
#
#      Heat Wave Duration  dur_ranking  stage                        NAME  \
# 0                   2.0     0.094401    1.0  Alameda County, California
# 1                   2.0     0.094401    2.0  Alameda County, California
# 2                   2.0     0.094401    1.0  Alameda County, California
# 3                   2.0     0.094401    2.0  Alameda County, California
# 4                   8.0     0.861016    1.0  Alameda County, California
# ...                 ...          ...    ...                         ...
# 1248                5.0     0.575697    1.0                         NaN
# 1249                5.0     0.575697    2.0                         NaN
# 1250                5.0     0.575697    3.0                         NaN
# 1251                5.0     0.575697    4.0                         NaN
# 1252                5.0     0.575697    5.0                         NaN
#
#       over65_dec  income_dec  nonwhite_dec         district
# 0              3          10            10              NaN
# 1              3          10            10              NaN
# 2              3          10            10              NaN
# 3              3          10            10              NaN
# 4              3          10            10              NaN
# ...          ...         ...           ...              ...
# 1248           5           6             6  Thompson-Nicola
# 1249           5           6             6  Thompson-Nicola
# 1250           5           6             6  Thompson-Nicola
# 1251           5           6             6  Thompson-Nicola
# 1252           5           6             6  Thompson-Nicola
#
# [7415 rows x 59 columns]

# %%
mob_vars.drop('district', axis=1, inplace=True)

# %%
mob_vars = mob_vars.merge(pop_dens[['location', 'popdens_dec']], on='location')

# %%
mob_vars['income_dec'].value_counts()
# Out:
# 5     850
# 9     805
# 8     803
# 6     800
# 3     774
# 10    772
# 2     772
# 4     632
# 1     629
# 7     578
# Name: income_dec, dtype: int64

# %%
mob_vars[mob_vars['popdens_dec'] == 10]['location'].unique()
# Out:
# array(['Alameda County, California', 'Contra Costa County, California',
#        'Los Angeles County, California', 'Orange County, California',
#        'San Francisco County, California', 'San Mateo County, California',
#        'Clackamas County, Oregon', 'Marion County, Oregon',
#        'Multnomah County, Oregon', 'Washington County, Oregon',
#        'Clark County, Washington', 'King County, Washington',
#        'Kitsap County, Washington', 'Pierce County, Washington',
#        'Capital, British Columbia', 'Greater Vancouver, British Columbia',
#        'Nanaimo, British Columbia'], dtype=object)

# %%
mob_vars.to_csv(data_path + 'mobility_heat/mob_vars_final_clean_90.csv')

# %%
mob_vars.groupby('state')['temperature_2m_heat'].describe()
